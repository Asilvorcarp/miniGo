# %%
from ctypes import CFUNCTYPE, c_int
import sys

import llvmlite.binding as llvm
llvm.initialize()

# get ir string from file "build/main.o.ll"
ir = open("../build/sort.ll").read()

# the ModuleRef
mod = llvm.parse_assembly(ir)

mod.verify()

print(mod.triple)
print(mod.get_function("main_main"))

# llvm.shutdown()
# Out:
# x86_64-pc-linux-gnu
# define void @main_main() {
#   %t189 = add i32 0, 10005
#   %t191 = mul i32 %t189, 4
#   %t192 = call noalias i8* @malloc(i32 %t191)
#   %t190 = bitcast i8* %t192 to i32*
#   %local_arr.14 = alloca i32*, align 4
#   store i32* %t190, i32** %local_arr.14, align 8
#   %local_n.15 = alloca i32, align 4
#   store i32 0, i32* %local_n.15, align 4
#   %t193 = call i32 @main_getInt()
#   store i32 %t193, i32* %local_n.15, align 4
#   %t198 = add i32 0, 0
#   %local_i.16 = alloca i32, align 4
#   store i32 %t198, i32* %local_i.16, align 4
#   br label %for.cond10.194
#
# for.cond10.194:                                   ; preds = %for.post10.195, %0
#   %t200 = load i32, i32* %local_i.16, align 4
#   %t201 = load i32, i32* %local_n.15, align 4
#   %t199 = icmp slt i32 %t200, %t201
#   br i1 %t199, label %for.body10.196, label %for.end10.197
#
# for.body10.196:                                   ; preds = %for.cond10.194
#   %t202 = call i32 @main_getInt()
#   %t203 = load i32, i32* %local_i.16, align 4
#   %t204 = load i32*, i32** %local_arr.14, align 4
#   %t205 = getelementptr inbounds i32, i32* %t204, i32 %t203
#   store i32 %t202, i32* %t205, align 4
#   br label %for.post10.195
#
# for.post10.195:                                   ; preds = %for.body10.196
#   %t206 = load i32, i32* %local_i.16, align 4
#   %t207 = add i32 %t206, 1
#   store i32 %t207, i32* %local_i.16, align 4
#   br label %for.cond10.194
#
# for.end10.197:                                    ; preds = %for.cond10.194
#   %t208 = load i32*, i32** %local_arr.14, align 4
#   %t209 = add i32 0, 0
#   %t211 = load i32, i32* %local_n.15, align 4
#   %t212 = add i32 0, 1
#   %t210 = sub i32 %t211, %t212
#   call void @main_quicksort(i32* %t208, i32 %t209, i32 %t210)
#   %t217 = add i32 0, 0
#   %local_i.17 = alloca i32, align 4
#   store i32 %t217, i32* %local_i.17, align 4
#   br label %for.cond11.213
#
# for.cond11.213:                                   ; preds = %for.post11.214, %for.end10.197
#   %t219 = load i32, i32* %local_i.17, align 4
#   %t220 = load i32, i32* %local_n.15, align 4
#   %t218 = icmp slt i32 %t219, %t220
#   br i1 %t218, label %for.body11.215, label %for.end11.216
#
# for.body11.215:                                   ; preds = %for.cond11.213
#   %t221 = load i32, i32* %local_i.17, align 4
#   %t222 = load i32*, i32** %local_arr.14, align 4
#   %t223 = getelementptr inbounds i32, i32* %t222, i32 %t221
#   %t224 = load i32, i32* %t223, align 4
#   call void @main_putInt(i32 %t224)
#   %t225 = add i32 0, 10
#   %t226 = call i32 @putchar(i32 %t225)
#   br label %for.post11.214
#
# for.post11.214:                                   ; preds = %for.body11.215
#   %t227 = load i32, i32* %local_i.17, align 4
#   %t228 = add i32 %t227, 1
#   store i32 %t228, i32* %local_i.17, align 4
#   br label %for.cond11.213
#
# for.end11.216:                                    ; preds = %for.cond11.213
#   ret void
# }

# %%
import copy
from random import choice
from typing import Optional, Union, Any, Set, List, Tuple, Dict, Collection
from llvmlite.binding import ValueRef


# for i in mod.functions:
#     if i.is_declaration:
#         continue
#     print(i)
#     i.arguments

main = mod.get_function("main_quicksort")
# print(main)
# putABC = mod.get_function("main_putABC")
# print(putABC)
# [print(i) for i in putABC.arguments]

ins: List[ValueRef] = []
allocas: Dict[str, int] = {}
useDef: Dict[int, List[Any]] = {}
labelToIdx: Dict[str, int] = {}

for b in main.blocks:
    labelToIdx[b.name] = len(
        [_ for _ in ins if _.opcode not in ["alloca", "bitcast"]]) # TODO ensure this
    ins += [_ for _ in b.instructions]

print(labelToIdx)

idxToLabel = {value: key for key, value in labelToIdx.items()}

# collect allocas and construct use-def chain
idx = 0
for i in ins:
    op = i.opcode
    if op == "alloca":
        # TODO spill also increase size
        if str(i.type) == "i32*":
            allocas[i.name] = 4
        else:
            allocas[i.name] = 8
        idx -= 1
    elif op == "bitcast":
        idx -= 1
    elif op == "store":
        use = []
        for j in i.operands:
            if j.name != "" and j.name not in allocas:
                use.append(j.name)
        useDef[idx] = [i, set(use), set()]
    elif op == "br":
        use = []
        for j in i.operands:
            if str(j.type) != "label":
                if j.name != "" and j.name not in allocas:
                    use.append(j.name)
        useDef[idx] = [i, set(use), set()]
    elif op == "call":
        use = []
        defs = []
        if i.name != "":
            defs.append(i.name)
        for j in i.operands:
            isFnType = '(' in str(j.type) and ')' in str(j.type)
            if not isFnType and j.name != "" and j.name not in allocas:
                use.append(j.name)
        useDef[idx] = [i, set(use), set(defs)]
    else:
        use = []
        defs = []
        if i.name != "":
            defs.append(i.name)
        for j in i.operands:
            if j.name != "" and j.name not in allocas:
                use.append(j.name)
        useDef[idx] = [i, set(use), set(defs)]
    idx += 1

# get succ
for idx in useDef:
    if idx == len(useDef)-1:
        useDef[idx].insert(1, [])
        continue
    theI = useDef[idx][0]
    op = theI.opcode
    if op == "br":
        print(theI)
        labels: List[ValueRef] = [
            _ for _ in theI.operands if str(_.type) == "label"]
        useDef[idx].insert(1, [labelToIdx[_.name] for _ in labels])
    else:
        useDef[idx].insert(1, [idx+1])

# print useDef
for i in useDef:
    print(i, useDef[i][1:])

# get out in
theIn = [set() for _ in useDef]
theOut = [set() for _ in useDef]
theIn2 = [set() for _ in useDef]
theOut2 = [set() for _ in useDef]

init = 1

def pretty(s: Set[str]):
    return "{" + ", ".join(s) + "}"

def done():
    global init
    if init:
        init = 0
        return False
    for i in range(len(theIn)):
        if theIn[i] != theIn2[i] or theOut[i] != theOut2[i]:
            return False
    print("done")
    return True

count = 0
while not done():
# for ff in range(9):
    count += 1
    theIn2 = copy.deepcopy(theIn)
    theOut2 = copy.deepcopy(theOut)
    # reverse
    for idx in range(len(useDef)-1, -1, -1):
        theIn[idx] = useDef[idx][2] | (theOut[idx] - useDef[idx][3])
        theOut[idx] = set()
        for succ in useDef[idx][1]:
            theOut[idx] |= theIn[succ]
print("count", count)

# print def use in out
for i in range(len(theIn)):
    print(i, pretty(useDef[i][3]), pretty(useDef[i][2]), "|", pretty(theIn[i]), pretty(theOut[i]))

print(allocas)
local = 8 * len(allocas)
print(local)
# Out:
# {'': 0, 'if.body5.81': 7, 'if.end5.83': 25}
#   br i1 %t84, label %if.body5.81, label %if.end5.83
#   br label %if.end5.83
# 0 [[1], {'local_arr.4.arg0'}, set()]
# 1 [[2], {'local_left.5.arg1'}, set()]
# 2 [[3], {'local_right.6.arg2'}, set()]
# 3 [[4], set(), {'t85'}]
# 4 [[5], set(), {'t86'}]
# 5 [[6], {'t86', 't85'}, {'t84'}]
# 6 [[25, 7], {'t84'}, set()]
# 7 [[8], set(), {'t87'}]
# 8 [[9], set(), {'t88'}]
# 9 [[10], set(), {'t89'}]
# 10 [[11], {'t87', 't89', 't88'}, {'t90'}]
# 11 [[12], {'t90'}, set()]
# 12 [[13], set(), {'t91'}]
# 13 [[14], set(), {'t92'}]
# 14 [[15], set(), {'t94'}]
# 15 [[16], set(), {'t95'}]
# 16 [[17], {'t94', 't95'}, {'t93'}]
# 17 [[18], {'t92', 't91', 't93'}, set()]
# 18 [[19], set(), {'t96'}]
# 19 [[20], set(), {'t98'}]
# 20 [[21], set(), {'t99'}]
# 21 [[22], {'t99', 't98'}, {'t97'}]
# 22 [[23], set(), {'t100'}]
# 23 [[24], {'t97', 't100', 't96'}, set()]
# 24 [[25], set(), set()]
# 25 [[], set(), set()]
# done
# count 6
# 0 {} {local_arr.4.arg0} | {local_left.5.arg1, local_arr.4.arg0, local_right.6.arg2} {local_left.5.arg1, local_right.6.arg2}
# 1 {} {local_left.5.arg1} | {local_left.5.arg1, local_right.6.arg2} {local_right.6.arg2}
# 2 {} {local_right.6.arg2} | {local_right.6.arg2} {}
# 3 {t85} {} | {} {t85}
# 4 {t86} {} | {t85} {t86, t85}
# 5 {t84} {t86, t85} | {t86, t85} {t84}
# 6 {} {t84} | {t84} {}
# 7 {t87} {} | {} {t87}
# 8 {t88} {} | {t87} {t87, t88}
# 9 {t89} {} | {t87, t88} {t87, t89, t88}
# 10 {t90} {t87, t89, t88} | {t87, t89, t88} {t90}
# 11 {} {t90} | {t90} {}
# 12 {t91} {} | {} {t91}
# 13 {t92} {} | {t91} {t92, t91}
# 14 {t94} {} | {t92, t91} {t92, t94, t91}
# 15 {t95} {} | {t92, t94, t91} {t92, t94, t91, t95}
# 16 {t93} {t94, t95} | {t92, t94, t91, t95} {t92, t91, t93}
# 17 {} {t92, t91, t93} | {t92, t91, t93} {}
# 18 {t96} {} | {} {t96}
# 19 {t98} {} | {t96} {t98, t96}
# 20 {t99} {} | {t98, t96} {t99, t98, t96}
# 21 {t97} {t99, t98} | {t99, t98, t96} {t97, t96}
# 22 {t100} {} | {t97, t96} {t97, t100, t96}
# 23 {} {t97, t100, t96} | {t97, t100, t96} {}
# 24 {} {} | {} {}
# 25 {} {} | {} {}
# {'local_arr.4': 8, 'local_left.5': 4, 'local_right.6': 4, 'local_pivotIndex.7': 4}
# 32

# %%
import matplotlib.pyplot as plt
import networkx as nx


class Graph:
    """
    The register interference graph.
    """

    def __init__(self):
        self._adjacency_list = {}

    def __copy__(self):
        cls = self.__class__
        new_graph = self.__new__(cls)
        new_graph._adjacency_list = copy.deepcopy(self._adjacency_list)
        return new_graph

    def add_edge(self, x, y):
        """
        Add an edge to the graph.
        The interference graph is undirected so add_edge('a', 'b') and add_edge('b', 'a') have the same effect.
        """
        # Add y to x
        x_list = self._adjacency_list.get(x, [])
        if y not in x_list:
            x_list.append(y)
        self._adjacency_list[x] = x_list

        # Add x to y
        y_list = self._adjacency_list.get(y, [])
        if x not in y_list:
            y_list.append(x)
        self._adjacency_list[y] = y_list

    def contains_edge(self, x, y):
        return y in self._adjacency_list.get(x, [])

    def remove_node(self, node):
        if node in self._adjacency_list:
            self._adjacency_list.pop(node)
        for key in self._adjacency_list.keys():
            if node in self._adjacency_list.get(key):
                self._adjacency_list.get(key).remove(node)

    def rename_node(self, from_label, to_label):
        from_list = self._adjacency_list.pop(from_label, [])
        to_list = self._adjacency_list.get(to_label, [])
        self._adjacency_list[to_label] = list(set(from_list + to_list))

        for key in self._adjacency_list.keys():
            self._adjacency_list[key] = list(set(
                [to_label if value ==
                    from_label else value for value in self._adjacency_list[key]]
            ))

    def neighbors(self, x):
        return self._adjacency_list.get(x, [])

    def plot(self, coloring, title):
        G = nx.Graph()

        # Sorting to get repeatable graphs
        nodes = sorted(self._adjacency_list.keys())
        ordered_coloring = [coloring.get(node, 'grey') for node in nodes]
        G.add_nodes_from(nodes)

        for key in self._adjacency_list.keys():
            for value in self._adjacency_list[key]:
                G.add_edge(key, value)

        plt.title(title)
        nx.draw(G, pos=nx.circular_layout(G), node_color=ordered_coloring,
                with_labels=True, font_weight='bold')
        plt.show()
    
    def all_nodes(self):
        return self._adjacency_list.keys()


def color_graph(g: Graph, regs: Collection[str], colors: List[str]) -> Optional[Dict[str, str]]:
    if len(regs) == 0:
        return {}

    node = next((node for node in regs if len(
        g.neighbors(node)) < len(colors)), None)
    if node is None:
        return None

    g_copy = copy.copy(g)
    g_copy.remove_node(node)
    coloring = color_graph(g_copy, [n for n in regs if n != node], colors)
    if coloring is None:
        return None

    neighbor_colors = [coloring[neighbor] for neighbor in g.neighbors(node)]
    coloring[node] = [color for color in colors if color not in neighbor_colors][0]

    return coloring

allTemp = set.union(*([useDef[idx][2]
                       for idx in useDef] + [useDef[idx][3] for idx in useDef]))
print(allTemp)

def build_graph() -> Graph:
    g = Graph()
    # for t in allTemp:
    #     print("add", t)
    #     g.add_edge(t, t)
    for idx in useDef:
        outs = theOut[idx]
        defs = useDef[idx][3]
        for aDef in defs:
            for aOut in outs:
                if aDef != aOut:
                    print("add", aDef, aOut)
                    g.add_edge(aDef, aOut)
    return g


g = build_graph()
colors = [i for i in range(8)]
coloring = color_graph(g, list(allTemp), colors)
print("coloring", coloring)
g.plot(coloring, "Interference Graph")
print("single nodes:", set(allTemp) - set(g.all_nodes()))
print("color needed:", len(set(coloring.values())))
# Out:
# {'t86', 'local_left.5.arg1', 't87', 't96', 't89', 't88', 't85', 't97', 't100', 't90', 'local_right.6.arg2', 't84', 't94', 't98', 't92', 'local_arr.4.arg0', 't99', 't91', 't93', 't95'}
# add t86 t85
# add t88 t87
# add t89 t87
# add t89 t88
# add t92 t91
# add t94 t92
# add t94 t91
# add t95 t92
# add t95 t94
# add t95 t91
# add t93 t92
# add t93 t91
# add t98 t96
# add t99 t98
# add t99 t96
# add t97 t96
# add t100 t97
# add t100 t96
# coloring {'t95': 0, 't93': 0, 't91': 1, 't99': 0, 'local_arr.4.arg0': 0, 't92': 2, 't98': 1, 't94': 3, 't84': 0, 'local_right.6.arg2': 0, 't90': 0, 't100': 0, 't97': 1, 't85': 0, 't88': 0, 't89': 1, 't96': 2, 't87': 2, 'local_left.5.arg1': 0, 't86': 1}
# single nodes: {'local_left.5.arg1', 'local_arr.4.arg0', 't90', 'local_right.6.arg2', 't84'}
# color needed: 4

# %%
# get depth in the stack
depth: Dict[str, int] = {}
for k, v in allocas.items():
    sum = 0
    for k2, v2 in allocas.items():
        sum += v2
        if k == k2:
            break
    depth[k] = sum
print("depth", depth)

# to real register

def toR(reg: str | ValueRef) -> str:
    if reg.name != '':
        reg = reg.name
    else:
        reg = str(reg)
    # now: "i32 0" / "t99"
    print("toR", reg)
    if 'i32' in reg:
        _, n = reg.split(' ')
        return f"${n}"
    elif '.arg' in reg:
        _, n = reg.split('.arg')
        n = int(n)
        if n == 0:
            return "%rdi"
        elif n == 1:
            return "%rsi"
        elif n == 2:
            return "%rdx"
        elif n == 3:
            return "%rcx"
        elif n == 4:
            raise Exception("too many args (>4)")
    elif 'local_' in reg:
        return f'-{depth[reg]}(%rbp)'
    return f"%r{coloring[reg]+8}"


asm: List[str] = []
asm += [f"pushq %rbp"]
asm += [f"movq %rsp, %rbp"]
asm += [f"subq ${local}, %rsp"]
brType = 'jz' # for and or
for idx in useDef:
    i : ValueRef = useDef[idx][0]
    print(">", i)
    op = i.opcode
    regs = [_ for _ in i.operands]
    cmds = []
    # insert label
    label = idxToLabel.get(idx, None)
    if label != None:
        asm += [f'{label}:']
    if op == "add":
        rs1 = toR(regs[0])
        rs2 = toR(regs[1])
        rd = toR(i)
        cmd1 = f"movq {rs1}, {rd}"
        cmd2 = f"addq {rs2}, {rd}"
        cmds = [cmd1, cmd2]
    elif op == 'store':
        rs = toR(regs[0])
        # TODO ensure () here
        rd = toR(regs[1])
        cmd = f"movq {rs}, {rd}"
        cmds = [cmd]
    elif op == 'load':
        rd = toR(i)
        # TODO ensure () here
        rs = toR(regs[0])
        cmd = f'movq {rs}, {rd}'
        cmds = [cmd]
    elif op == 'call':
        pass
    elif op == 'icmp':
        # slt, ...
        exactType = str(i).split('icmp ')[1].split()[0]
        # ! assert first label is always next
        theMap = {
            'eq': 'jne',
            'ne': 'je',
            'slt': 'jge',
            'sle': 'jg',
            'sgt': 'jle',
            'sge': 'jl',
        }
        tryGet = theMap.get(exactType, None)
        if tryGet!=None:
            brType = tryGet
        else:
            raise Exception("Unknown icmp type")
    elif op == 'br':
        labels = []
        for j in regs:
            if str(j.type) == "label":
                labels.append(j.name)
        pass
    else:
        cmds = ["TODO"]
    brType = 'jz' # abondon if not used
    asm += cmds
    print("  -", cmds)
asm += [f"movq %rbp, %rsp"]
asm += [f"popq %rbp"]
asm += [f"retq"]

print("-- ASM: --")
print("\n".join(asm))
# Out:
# depth {'local_arr.4': 8, 'local_left.5': 12, 'local_right.6': 16, 'local_pivotIndex.7': 20}
# >   store i32* %local_arr.4.arg0, i32** %local_arr.4, align 8
# toR local_arr.4.arg0
# toR local_arr.4
#   - ['movq %rdi, -8(%rbp)']
# >   store i32 %local_left.5.arg1, i32* %local_left.5, align 4
# toR local_left.5.arg1
# toR local_left.5
#   - ['movq %rsi, -12(%rbp)']
# >   store i32 %local_right.6.arg2, i32* %local_right.6, align 4
# toR local_right.6.arg2
# toR local_right.6
#   - ['movq %rdx, -16(%rbp)']
# >   %t85 = load i32, i32* %local_left.5, align 4
# toR t85
# toR local_left.5
#   - ['movq -12(%rbp), %r8']
# >   %t86 = load i32, i32* %local_right.6, align 4
# toR t86
# toR local_right.6
#   - ['movq -16(%rbp), %r9']
# >   %t84 = icmp slt i32 %t85, %t86
# slt
#   - []
# >   br i1 %t84, label %if.body5.81, label %if.end5.83
#   - []
# >   %t87 = load i32*, i32** %local_arr.4, align 4
# toR t87
# toR local_arr.4
#   - ['movq -8(%rbp), %r10']
# >   %t88 = load i32, i32* %local_left.5, align 4
# toR t88
# toR local_left.5
#   - ['movq -12(%rbp), %r8']
# >   %t89 = load i32, i32* %local_right.6, align 4
# toR t89
# toR local_right.6
#   - ['movq -16(%rbp), %r9']
# >   %t90 = call i32 @main_partition(i32* %t87, i32 %t88, i32 %t89)
#   - []
# >   store i32 %t90, i32* %local_pivotIndex.7, align 4
# toR t90
# toR local_pivotIndex.7
#   - ['movq %r8, -20(%rbp)']
# >   %t91 = load i32*, i32** %local_arr.4, align 4
# toR t91
# toR local_arr.4
#   - ['movq -8(%rbp), %r9']
# >   %t92 = load i32, i32* %local_left.5, align 4
# toR t92
# toR local_left.5
#   - ['movq -12(%rbp), %r10']
# >   %t94 = load i32, i32* %local_pivotIndex.7, align 4
# toR t94
# toR local_pivotIndex.7
#   - ['movq -20(%rbp), %r11']
# >   %t95 = add i32 0, 1
# toR i32 0
# toR i32 1
# toR t95
#   - ['movq $0, %r8', 'addq $1, %r8']
# >   %t93 = sub i32 %t94, %t95
#   - ['TODO']
# >   call void @main_quicksort(i32* %t91, i32 %t92, i32 %t93)
#   - []
# >   %t96 = load i32*, i32** %local_arr.4, align 4
# toR t96
# toR local_arr.4
#   - ['movq -8(%rbp), %r10']
# >   %t98 = load i32, i32* %local_pivotIndex.7, align 4
# toR t98
# toR local_pivotIndex.7
#   - ['movq -20(%rbp), %r9']
# >   %t99 = add i32 0, 1
# toR i32 0
# toR i32 1
# toR t99
#   - ['movq $0, %r8', 'addq $1, %r8']
# >   %t97 = add i32 %t98, %t99
# toR t98
# toR t99
# toR t97
#   - ['movq %r9, %r9', 'addq %r8, %r9']
# >   %t100 = load i32, i32* %local_right.6, align 4
# toR t100
# toR local_right.6
#   - ['movq -16(%rbp), %r8']
# >   call void @main_quicksort(i32* %t96, i32 %t97, i32 %t100)
#   - []
# >   br label %if.end5.83
#   - []
# >   ret void
#   - ['TODO']
# -- ASM: --
# pushq %rbp
# movq %rsp, %rbp
# subq $32, %rsp
# movq %rdi, -8(%rbp)
# movq %rsi, -12(%rbp)
# movq %rdx, -16(%rbp)
# movq -12(%rbp), %r8
# movq -16(%rbp), %r9
# movq -8(%rbp), %r10
# movq -12(%rbp), %r8
# movq -16(%rbp), %r9
# movq %r8, -20(%rbp)
# movq -8(%rbp), %r9
# movq -12(%rbp), %r10
# movq -20(%rbp), %r11
# movq $0, %r8
# addq $1, %r8
# TODO
# movq -8(%rbp), %r10
# movq -20(%rbp), %r9
# movq $0, %r8
# addq $1, %r8
# movq %r9, %r9
# addq %r8, %r9
# movq -16(%rbp), %r8
# TODO
# movq %rbp, %rsp
# popq %rbp
# retq
