# %%
# %%
import os
import llvmlite.binding as llvm
import copy
from random import choice
from typing import Literal, Optional, Union, Any, Set, List, Tuple, Dict, Collection
from llvmlite.binding import ValueRef
import matplotlib
import matplotlib.pyplot as plt
import networkx as nx
import argparse


class Graph:
    def __init__(self):
        self._adjacency_list = {}

    def __copy__(self):
        cls = self.__class__
        new_graph = self.__new__(cls)
        new_graph._adjacency_list = copy.deepcopy(self._adjacency_list)
        return new_graph

    def add_edge(self, x, y):
        # Add y to x
        x_list = self._adjacency_list.get(x, [])
        if y not in x_list:
            x_list.append(y)
        self._adjacency_list[x] = x_list

        # Add x to y
        y_list = self._adjacency_list.get(y, [])
        if x not in y_list:
            y_list.append(x)
        self._adjacency_list[y] = y_list

    def contains_edge(self, x, y):
        return y in self._adjacency_list.get(x, [])

    def remove_node(self, node):
        if node in self._adjacency_list:
            self._adjacency_list.pop(node)
        for key in self._adjacency_list.keys():
            if node in self._adjacency_list.get(key):
                self._adjacency_list.get(key).remove(node)

    def rename_node(self, from_label, to_label):
        from_list = self._adjacency_list.pop(from_label, [])
        to_list = self._adjacency_list.get(to_label, [])
        self._adjacency_list[to_label] = list(set(from_list + to_list))

        for key in self._adjacency_list.keys():
            self._adjacency_list[key] = list(set(
                [to_label if value ==
                    from_label else value for value in self._adjacency_list[key]]
            ))

    def neighbors(self, x):
        return self._adjacency_list.get(x, [])

    def plot(self, coloring, title,
             action: Literal['output', 'show', 'none'] = 'output'):
        G = nx.Graph()

        # Sorting to get repeatable graphs
        nodes = sorted(self._adjacency_list.keys())
        ordered_coloring = [coloring.get(node, 'grey') for node in nodes]
        G.add_nodes_from(nodes)

        for key in self._adjacency_list.keys():
            for value in self._adjacency_list[key]:
                G.add_edge(key, value)

        if action != 'show':
            matplotlib.use('Agg')

        plt.title(title+"\nInterference Graph")
        plt.size = (20, 20)
        # other layout available at https://networkx.org/documentation/stable/reference/drawing.html
        nx.draw(G, pos=nx.shell_layout(G), node_color=ordered_coloring,
                with_labels=True)

        if action == 'output':
            # make sure the directory exists
            os.makedirs(os.path.dirname(
                f"build/graph/{title}.png"), exist_ok=True)
            plt.savefig(f"build/graph/{title}.png")
        elif action == 'show':
            plt.show()

    def all_nodes(self):
        return self._adjacency_list.keys()


def color_graph(g: Graph, regs: Collection[str], colors: List[str]) -> Optional[Dict[str, str]]:
    if len(regs) == 0:
        return {}

    node = next((node for node in regs if len(
        g.neighbors(node)) < len(colors)), None)
    if node is None:
        return None

    g_copy = copy.copy(g)
    g_copy.remove_node(node)
    coloring = color_graph(g_copy, [n for n in regs if n != node], colors)
    if coloring is None:
        return None

    neighbor_colors = [coloring[neighbor] for neighbor in g.neighbors(node)]
    coloring[node] = [
        color for color in colors if color not in neighbor_colors][0]

    return coloring


def save() -> List[str]:
    return [f"pushq %r{x}" for x in range(8, 16)]


def restore() -> List[str]:
    return [f"popq %r{x}" for x in range(8, 16)][::-1]


def codeGenForFunc(fn: ValueRef, globalNames: List[str],
                   action: Literal['output', 'show', 'none'] = 'output') -> List[str]:
    funcName = fn.name
    print("codeGenForFunc", funcName)

    ins: List[ValueRef] = []
    allocas: Dict[str, int] = {}
    useDef: Dict[int, List[Any]] = {}
    labelToIdx: Dict[str, int] = {}

    for b in fn.blocks:
        labelToIdx[b.name] = len(
            [_ for _ in ins if _.opcode not in ["alloca"]])  # TODO ensure this
        ins += [_ for _ in b.instructions]
    # if '' in labelToIdx.keys():
    labelToIdx.pop("")

    print(labelToIdx)

    idxToLabel = {value: key for key, value in labelToIdx.items()}

    # collect allocas and construct use-def chain
    idx = 0
    for i in ins:
        op = i.opcode
        if op == "alloca":
            # TODO spill also increase size
            # TODO not actually alloca for arg4+
            if str(i.type) == "i32*":
                # allocas[i.name] = 4
                allocas[i.name] = 8
            else:
                allocas[i.name] = 8
            idx -= 1
        elif op == "store":
            use = []
            for j in i.operands:
                if j.name != "" and j.name not in allocas:
                    use.append(j.name)
            useDef[idx] = [i, set(use), set()]
        elif op == "br":
            use = []
            for j in i.operands:
                if str(j.type) != "label":
                    if j.name != "" and j.name not in allocas:
                        use.append(j.name)
            useDef[idx] = [i, set(use), set()]
        elif op == "call":
            use = []
            defs = []
            if i.name != "":
                defs.append(i.name)
            for j in i.operands:
                isFnType = '(' in str(j.type) and ')' in str(j.type)
                if not isFnType and j.name != "" and j.name not in allocas:
                    use.append(j.name)
            useDef[idx] = [i, set(use), set(defs)]
        else:
            use = []
            defs = []
            if i.name != "":
                defs.append(i.name)
            for j in i.operands:
                if j.name != "" and j.name not in allocas:
                    use.append(j.name)
            useDef[idx] = [i, set(use), set(defs)]
        idx += 1

    # get succ
    for idx in useDef:
        if idx == len(useDef)-1:
            useDef[idx].insert(1, [])
            continue
        theI = useDef[idx][0]
        op = theI.opcode
        if op == "br":
            print(theI)
            labels: List[ValueRef] = [
                _ for _ in theI.operands if str(_.type) == "label"]
            useDef[idx].insert(1, [labelToIdx[_.name] for _ in labels])
        else:
            useDef[idx].insert(1, [idx+1])

    # print useDef
    for i in useDef:
        print(i, useDef[i][1:])

    # get out in
    theIn = [set() for _ in useDef]
    theOut = [set() for _ in useDef]
    theIn2 = [set() for _ in useDef]
    theOut2 = [set() for _ in useDef]

    init = 1

    def pretty(s: Set[str]):
        return "{" + ", ".join(s) + "}"

    def done():
        nonlocal init
        if init:
            init = 0
            return False
        for i in range(len(theIn)):
            if theIn[i] != theIn2[i] or theOut[i] != theOut2[i]:
                return False
        print("done")
        return True

    count = 0
    while not done():
        # for ff in range(9):
        count += 1
        theIn2 = copy.deepcopy(theIn)
        theOut2 = copy.deepcopy(theOut)
        # reverse
        for idx in range(len(useDef)-1, -1, -1):
            theIn[idx] = useDef[idx][2] | (theOut[idx] - useDef[idx][3])
            theOut[idx] = set()
            for succ in useDef[idx][1]:
                theOut[idx] |= theIn[succ]
    print("count", count)

    # print def use in out
    for i in range(len(theIn)):
        print(i, pretty(useDef[i][3]), pretty(useDef[i][2]),
              "|", pretty(theIn[i]), pretty(theOut[i]))

    print(allocas)
    local = 8 * len(allocas)
    print(local)

    allTemp = set.union(*([useDef[idx][2]
                        for idx in useDef] + [useDef[idx][3] for idx in useDef]))
    print(allTemp)

    def build_graph() -> Graph:
        g = Graph()
        # for t in allTemp:
        #     print("add", t)
        #     g.add_edge(t, t)
        for idx in useDef:
            outs = theOut[idx]
            defs = useDef[idx][3]
            for aDef in defs:
                for aOut in outs:
                    if aDef != aOut:
                        print("add", aDef, aOut)
                        g.add_edge(aDef, aOut)
        return g

    g = build_graph()
    colors = [i for i in range(8)]
    coloring = color_graph(g, list(allTemp), colors)
    print("coloring", coloring)
    print("single nodes:", set(allTemp) - set(g.all_nodes()))
    print("color needed:", len(set(coloring.values())))
    g.plot(coloring, funcName, action)
    # get depth in the stack
    depth: Dict[str, int] = {}
    for k, v in allocas.items():
        sum = 0
        for k2, v2 in allocas.items():
            sum += v2
            if k == k2:
                break
        depth[k] = sum
    print("depth", depth)

    # to real register
    def toR(reg: str | ValueRef, deRefer=False) -> str:
        if reg.name != '':
            reg = reg.name
        else:
            reg = str(reg)
        # now: "i32 0" / "t99"
        print("toR", reg)  # debug
        if 'i32' in reg or 'i64' in reg:
            _, n = reg.split(' ')
            if n == 'null':
                return '$0'
            return f"${n}"
        elif deRefer and reg in globalNames:
            # note: this is a ptr, caller should derefer it
            return f"{reg}@GOTPCREL(%rip)"
        elif '.arg' in reg:
            X, n = reg.split('.arg')
            n = int(n)
            if n == 0:
                return "%rdi"
            elif n == 1:
                return "%rsi"
            elif n == 2:
                return "%rdx"
            elif n == 3:
                return "%rcx"
            elif n >= 4:
                # update depth
                # ! assert X.argN => (X)
                # ra, rbp at 0, 8
                depth[X] = -((n-4)*8+16)
                return f'{-depth[X]}(%rbp)'
        elif deRefer and 'local_' in reg:
            return f'{-depth[reg]}(%rbp)'
        if deRefer:
            return f'(%r{coloring[reg]+8})'
        return f"%r{coloring[reg]+8}"

    asm: List[str] = []
    asm += [f"\t.globl {funcName}"]
    asm += [f"\t{funcName}:"]
    asm += [f"pushq %rbp"]
    asm += [f"movq %rsp, %rbp"]
    asm += [f"subq ${local}, %rsp"]
    asm += save()
    for idx in useDef:
        i: ValueRef = useDef[idx][0]
        print(">", i)
        op = i.opcode
        regs = [_ for _ in i.operands]
        cmds = []
        # insert label
        label = idxToLabel.get(idx, None)
        if label != None:
            asm += [f'\t{label}:']
        if op == "add":
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            # do not overwrite rs2
            if rd == rs2:
                rs1, rs2 = rs2, rs1
            cmd1 = f"movq {rs1}, {rd}"
            cmd2 = f"addq {rs2}, {rd}"
            cmds = [cmd1, cmd2]
        elif op == "sub":
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            toProtect = []
            insert = []
            if rd == rs2:
                insert = [f"movq {rs2}, %rcx"]
                rs2 = "%rcx"
                toProtect += ['%rcx']
            cmds += [f"pushq {r}" for r in toProtect]
            cmds += insert
            cmds += [f"movq {rs1}, {rd}"]
            cmds += [f"subq {rs2}, {rd}"]
            cmds += [f"popq {r}" for r in toProtect][::-1]
        elif op == "or":
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            # do not overwrite rs2
            if rd == rs2:
                rs1, rs2 = rs2, rs1
            cmd1 = f"movq {rs1}, {rd}"
            cmd2 = f"orq {rs2}, {rd}"
            cmds = [cmd1, cmd2]
        elif op == "and":
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            # do not overwrite rs2
            if rd == rs2:
                rs1, rs2 = rs2, rs1
            cmd1 = f"movq {rs1}, {rd}"
            cmd2 = f"andq {rs2}, {rd}"
            cmds = [cmd1, cmd2]
        elif op == "mul":
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            insert = []
            toProtect = ['%rax', '%rdx']
            # need to allocate a reg for const
            if '$' in rs2:
                insert = [f"movq {rs2}, %rcx"]
                rs2 = "%rcx"
                toProtect += ['%rcx']
            cmds += [f"pushq {r}" for r in toProtect]
            cmds += [f"movq {rs1}, %rax"]
            cmds += insert
            cmds += [f"imulq {rs2}"]
            cmds += [f"movq %rax, {rd}"]
            cmds += [f"popq {r}" for r in toProtect][::-1]
        elif op == "sdiv":
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            insert = []
            toProtect = ['%rax', '%rdx']
            # need to allocate a reg for const
            if '$' in rs2:
                insert = [f"movq {rs2}, %rcx"]
                rs2 = "%rcx"
                toProtect += ['%rcx']
            cmds += [f"pushq {r}" for r in toProtect]
            cmds += [f"movq {rs1}, %rax"]
            cmds += [f"cqto"]
            cmds += insert
            cmds += [f"idivq {rs2}"]
            cmds += [f"movq %rax, {rd}"]
            cmds += [f"popq {r}" for r in toProtect][::-1]
        elif op == "srem":
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            insert = []
            toProtect = ['%rax', '%rdx']
            # need to allocate a reg for const
            if '$' in rs2:
                insert = [f"movq {rs2}, %rcx"]
                rs2 = "%rcx"
                toProtect += ['%rcx']
            cmds += [f"pushq {r}" for r in toProtect]
            cmds += [f"movq {rs1}, %rax"]
            cmds += [f"cqto"]
            cmds += insert
            cmds += [f"idivq {rs2}"]
            cmds += [f"movq %rdx, {rd}"]
            cmds += [f"popq {r}" for r in toProtect][::-1]
        elif op == 'store':
            rs = toR(regs[0])
            rd = toR(regs[1], True)
            if '(%rbp)' in rs:
                # arg4+, in stack, no need to store
                cmds = []
            elif '@GOTPCREL' in rd:
                # global var, deRefer here
                cmds = [f"movq {rd}, %rax", f"movq {rs}, (%rax)"]
            else:
                cmds = [f"movq {rs}, {rd}"]
        elif op == 'load':
            rd = toR(i)
            rs = toR(regs[0], True)
            if '@GOTPCREL' in rs:
                # global var, deRefer here
                cmds = [f"movq {rs}, %rax", f"movq (%rax), {rd}"]
            else:
                cmds = [f'movq {rs}, {rd}']
        elif op == 'icmp':
            # slt, ...
            exactType = str(i).split('icmp ')[1].split()[0]
            # ! assert first label is always next
            toSet = {
                'eq': 'sete',
                'ne': 'setne',
                'slt': 'setl',
                'sle': 'setle',
                'sgt': 'setg',
                'sge': 'setge',
            }
            a = toR(regs[0])
            b = toR(regs[1])
            rd = toR(i)
            # this is "a-b"
            cmds += [f"pushq %rax"]
            cmds += [f"movq $0, %rax"]
            cmds += [f"cmpq {b}, {a}"]
            cmds += [f"{toSet[exactType]} %al"]
            cmds += [f"movq %rax, {rd}"]
            cmds += [f"popq %rax"]
        elif op == 'br':
            labels = []
            for j in regs:
                if str(j.type) == "label":
                    labels += [j.name]
            labels.reverse()  # the right order
            if len(labels) == 1 and labelToIdx.get(labels[0]) != idx+1:
                cmds = [f"jmp {labels[0]}"]
            elif len(labels) == 2:
                # asm += [f"\t{str(labels)}"]
                rs = toR(regs[0])
                cmds += [f"cmpq $0, {rs}"]
                cmds += [f"je {labels[1]}"]
        elif op == 'call':
            rd = toR(i) if i.name != '' else None
            fn = regs[-1].name + "@PLT"
            args = [toR(_) for _ in regs[:-1]]
            theMap = {
                0: "%rdi",
                1: "%rsi",
                2: "%rdx",
                3: "%rcx",
            }
            # args
            reversePush = []
            for x, arg in enumerate(args):
                if x < 4:
                    cmds += [f"movq {arg}, {theMap[x]}"]
                else:
                    reversePush += [f"pushq {arg}"]
            cmds += reversePush[::-1]
            cmds += [f"call {fn}"]
            if rd != None:
                cmds += [f"movq %rax, {rd}"]
        elif op == 'ret':
            if len(regs) != 0:
                res = toR(regs[0])
                cmds += [f"movq {res}, %rax"]
            cmds += [f"jmp {funcName}_end"]
        elif op == 'getelementptr':
            rs1 = toR(regs[0])
            rs2 = toR(regs[1])
            rd = toR(i)
            insert = []
            toProtect = []
            if '$' in rs2:
                # alloca reg for const
                insert += [f"movq {rs2}, %rax"]
                rs2 = "%rax"
                toProtect += ['%rax']
            cmds += [f"pushq {r}" for r in toProtect]
            cmds += insert
            cmds += [f"leaq ({rs1},{rs2},{8}), {rd}"]
            cmds += [f"popq {r}" for r in toProtect][::-1]
        elif op == 'bitcast':
            rs = toR(regs[0])
            rd = toR(i)
            cmd = f"movq {rs}, {rd}"
            cmds = [cmd]
        else:
            raise Exception(f"Unknown op: {op}")
        asm += [f'  #{str(i)}']
        asm += cmds
        print("  -", cmds)

    asm += [f"\t{funcName}_end:"]
    asm += restore()
    asm += [f"movq %rbp, %rsp"]
    asm += [f"popq %rbp"]
    asm += [f"retq"]

    print("-- ASM: --")
    print("\n".join(asm))

    return asm


def codeGenForGlobalVar(gv: ValueRef) -> List[str]:
    asm = []
    asm += [f"\t.globl	{gv.name}"]
    # asm += [f"\t.size	{gv.name}, 8"]
    asm += [f"{gv.name}:"]
    initializer = '0'
    type_str = str(gv.type)
    if type_str == 'i64*':
        asm += [f"\t.quad	{initializer}"]
    elif type_str == 'i32*':
        asm += [f"\t.long	{initializer}"]
    elif type_str == 'i8*':
        asm += [f"\t.byte	{initializer}"]
    else:
        raise Exception(f"Unknown global type: {type_str}")
    return asm


def codeGen(fileName: str, action: Literal['output', 'show', 'none'] = 'output') -> List[List[str]]:
    llvm.initialize()
    ir = open(fileName).read()
    # the ModuleRef
    mod = llvm.parse_assembly(ir)
    mod.verify()
    print(mod.triple)
    asms = []
    # get basename of fileName
    basename = os.path.basename(fileName)
    asms.append([f"\t.file	\"{basename}\""])
    globalNames = []
    bss = []
    bss.append([f"\t.bss"])
    for globalVar in mod.global_variables:
        if globalVar.is_declaration:
            continue
        asm = codeGenForGlobalVar(globalVar)
        bss.append(asm)
        globalNames.append(globalVar.name)
    text = []
    text.append([f"\t.text"])
    for fn in mod.functions:
        if fn.is_declaration:
            continue
        asm = codeGenForFunc(fn, globalNames, action)
        text.append(asm)
    # llvm.shutdown()
    asms += text + bss
    return asms


def ll2asm(inFile, outFile, action: Literal['output', 'show', 'none'] = 'output'):
    asms = codeGen(inFile, action)
    flat = ''
    flat += '\n'.join(['\n'.join(x + ['']) for x in asms])
    flat += '\n.section	".note.GNU-stack","",@progbits\n'
    # some simple optimization
    rm = []
    for line in flat.split('\n'):
        if line.startswith('movq'):
            if line.split()[1][:-1] == line.split()[2]:
                rm += [line]
    for line in rm:
        flat = flat.replace(line+'\n', '')
    # write to file
    with open(outFile, 'w') as f:
        f.write(flat)


# %%

# %%
fileName = '../build/global.debug.ll'

llvm.initialize()
ir = open(fileName).read()
# the ModuleRef
mod = llvm.parse_assembly(ir)
mod.verify()
print(mod.triple)

a:ValueRef = None
for gv in mod.global_variables:
    if gv.is_declaration:
        continue
    print(gv)
    a = gv
# Out:
# x86_64-pc-linux-gnu
# @main_g = global i64 0

# %%
str(a.type)
# str([_ for _ in a.linkage])
# Out:
# 'i64*'

# %%
ll2asm('../build/matrix.o.ll', 'global.s')
# Out:
# x86_64-pc-linux-gnu
# codeGenForFunc main_getInt
# {'for.0.cond': 7, 'for.0.body': 15, 'if.body1.12': 19, 'if.end1.14': 23, 'for.0.post': 26, 'for.0.end': 27, 'for.1.cond': 28, 'for.1.body': 36, 'for.1.post': 47, 'for.1.end': 48}
#   br label %for.0.cond
#   br i1 %t3, label %for.0.body, label %for.0.end
#   br i1 %t15, label %if.body1.12, label %if.end1.14
#   br label %if.end1.14
#   br label %for.0.post
#   br label %for.0.cond
#   br label %for.1.cond
#   br i1 %t21, label %for.1.body, label %for.1.end
#   br label %for.1.post
#   br label %for.1.cond
# 0 [[1], set(), {'t0'}]
# 1 [[2], {'t0'}, set()]
# 2 [[3], set(), {'t1'}]
# 3 [[4], {'t1'}, set()]
# 4 [[5], set(), {'t2'}]
# 5 [[6], {'t2'}, set()]
# 6 [[7], set(), set()]
# 7 [[8], set(), {'t5'}]
# 8 [[9], set(), {'t6'}]
# 9 [[10], {'t6', 't5'}, {'t4'}]
# 10 [[11], set(), {'t8'}]
# 11 [[12], set(), {'t9'}]
# 12 [[13], {'t9', 't8'}, {'t7'}]
# 13 [[14], {'t7', 't4'}, {'t3'}]
# 14 [[27, 15], {'t3'}, set()]
# 15 [[16], set(), {'t16'}]
# 16 [[17], set(), {'t17'}]
# 17 [[18], {'t16', 't17'}, {'t15'}]
# 18 [[23, 19], {'t15'}, set()]
# 19 [[20], set(), {'t19'}]
# 20 [[21], {'t19'}, {'t18'}]
# 21 [[22], {'t18'}, set()]
# 22 [[23], set(), set()]
# 23 [[24], set(), {'t20'}]
# 24 [[25], {'t20'}, set()]
# 25 [[26], set(), set()]
# 26 [[7], set(), set()]
# 27 [[28], set(), set()]
# 28 [[29], set(), {'t23'}]
# 29 [[30], set(), {'t24'}]
# 30 [[31], {'t23', 't24'}, {'t22'}]
# 31 [[32], set(), {'t26'}]
# 32 [[33], set(), {'t27'}]
# 33 [[34], {'t26', 't27'}, {'t25'}]
# 34 [[35], {'t22', 't25'}, {'t21'}]
# 35 [[48, 36], {'t21'}, set()]
# 36 [[37], set(), {'t31'}]
# 37 [[38], set(), {'t32'}]
# 38 [[39], {'t31', 't32'}, {'t30'}]
# 39 [[40], set(), {'t33'}]
# 40 [[41], {'t30', 't33'}, {'t29'}]
# 41 [[42], set(), {'t34'}]
# 42 [[43], {'t29', 't34'}, {'t28'}]
# 43 [[44], {'t28'}, set()]
# 44 [[45], set(), {'t35'}]
# 45 [[46], {'t35'}, set()]
# 46 [[47], set(), set()]
# 47 [[28], set(), set()]
# 48 [[49], set(), {'t37'}]
# 49 [[50], set(), {'t38'}]
# 50 [[51], {'t37', 't38'}, {'t36'}]
# 51 [[52], {'t36'}, set()]
# 52 [[53], set(), {'t39'}]
# 53 [[], {'t39'}, set()]
# done
# count 5
# 0 {t0} {} | {} {t0}
# 1 {} {t0} | {t0} {}
# 2 {t1} {} | {} {t1}
# 3 {} {t1} | {t1} {}
# 4 {t2} {} | {} {t2}
# 5 {} {t2} | {t2} {}
# 6 {} {} | {} {}
# 7 {t5} {} | {} {t5}
# 8 {t6} {} | {t5} {t6, t5}
# 9 {t4} {t6, t5} | {t6, t5} {t4}
# 10 {t8} {} | {t4} {t4, t8}
# 11 {t9} {} | {t4, t8} {t4, t9, t8}
# 12 {t7} {t9, t8} | {t4, t9, t8} {t7, t4}
# 13 {t3} {t7, t4} | {t7, t4} {t3}
# 14 {} {t3} | {t3} {}
# 15 {t16} {} | {} {t16}
# 16 {t17} {} | {t16} {t16, t17}
# 17 {t15} {t16, t17} | {t16, t17} {t15}
# 18 {} {t15} | {t15} {}
# 19 {t19} {} | {} {t19}
# 20 {t18} {t19} | {t19} {t18}
# 21 {} {t18} | {t18} {}
# 22 {} {} | {} {}
# 23 {t20} {} | {} {t20}
# 24 {} {t20} | {t20} {}
# 25 {} {} | {} {}
# 26 {} {} | {} {}
# 27 {} {} | {} {}
# 28 {t23} {} | {} {t23}
# 29 {t24} {} | {t23} {t23, t24}
# 30 {t22} {t23, t24} | {t23, t24} {t22}
# 31 {t26} {} | {t22} {t26, t22}
# 32 {t27} {} | {t26, t22} {t26, t22, t27}
# 33 {t25} {t26, t27} | {t26, t22, t27} {t22, t25}
# 34 {t21} {t22, t25} | {t22, t25} {t21}
# 35 {} {t21} | {t21} {}
# 36 {t31} {} | {} {t31}
# 37 {t32} {} | {t31} {t31, t32}
# 38 {t30} {t31, t32} | {t31, t32} {t30}
# 39 {t33} {} | {t30} {t30, t33}
# 40 {t29} {t30, t33} | {t30, t33} {t29}
# 41 {t34} {} | {t29} {t29, t34}
# 42 {t28} {t29, t34} | {t29, t34} {t28}
# 43 {} {t28} | {t28} {}
# 44 {t35} {} | {} {t35}
# 45 {} {t35} | {t35} {}
# 46 {} {} | {} {}
# 47 {} {} | {} {}
# 48 {t37} {} | {} {t37}
# 49 {t38} {} | {t37} {t37, t38}
# 50 {t36} {t37, t38} | {t37, t38} {t36}
# 51 {} {t36} | {t36} {}
# 52 {t39} {} | {} {t39}
# 53 {} {t39} | {t39} {}
# {'local_sign.0': 8, 'local_n.1': 8, 'local_c.2': 8}
# 24
# {'t9', 't8', 't22', 't29', 't2', 't16', 't20', 't28', 't1', 't31', 't30', 't6', 't34', 't5', 't17', 't38', 't27', 't7', 't36', 't15', 't24', 't32', 't0', 't37', 't4', 't3', 't18', 't33', 't35', 't25', 't26', 't23', 't21', 't19', 't39'}
# add t6 t5
# add t8 t4
# add t9 t4
# add t9 t8
# add t7 t4
# add t17 t16
# add t24 t23
# add t26 t22
# add t27 t26
# add t27 t22
# add t25 t22
# add t32 t31
# add t33 t30
# add t34 t29
# add t38 t37
# coloring {'t39': 0, 't19': 0, 't21': 0, 't23': 0, 't26': 0, 't25': 0, 't35': 0, 't33': 0, 't18': 0, 't3': 0, 't4': 0, 't37': 0, 't0': 0, 't32': 0, 't24': 1, 't15': 0, 't36': 0, 't7': 1, 't27': 1, 't38': 1, 't17': 0, 't5': 0, 't34': 0, 't6': 1, 't30': 1, 't31': 1, 't1': 0, 't28': 0, 't20': 0, 't16': 1, 't2': 0, 't29': 1, 't22': 2, 't8': 1, 't9': 2}
# single nodes: {'t15', 't0', 't36', 't28', 't2', 't3', 't20', 't18', 't1', 't35', 't21', 't19', 't39'}
# color needed: 3
# depth {'local_sign.0': 8, 'local_n.1': 16, 'local_c.2': 24}
# >   %t0 = add i64 0, 1
# toR i64 0
# toR i64 1
# toR t0
#   - ['movq $0, %r8', 'addq $1, %r8']
# >   store i64 %t0, i64* %local_sign.0, align 4
# toR t0
# toR local_sign.0
#   - ['movq %r8, -8(%rbp)']
# >   %t1 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t1
#   - ['movq $0, %r8', 'addq $0, %r8']
# >   store i64 %t1, i64* %local_n.1, align 4
# toR t1
# toR local_n.1
#   - ['movq %r8, -16(%rbp)']
# >   %t2 = call i64 @getchar()
# toR t2
#   - ['call getchar@PLT', 'movq %rax, %r8']
# >   store i64 %t2, i64* %local_c.2, align 4
# toR t2
# toR local_c.2
#   - ['movq %r8, -24(%rbp)']
# >   br label %for.0.cond
#   - []
# >   %t5 = load i64, i64* %local_c.2, align 4
# toR t5
# toR local_c.2
#   - ['movq -24(%rbp), %r8']
# >   %t6 = add i64 0, 48
# toR i64 0
# toR i64 48
# toR t6
#   - ['movq $0, %r9', 'addq $48, %r9']
# >   %t4 = icmp slt i64 %t5, %t6
# toR t5
# toR t6
# toR t4
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setl %al', 'movq %rax, %r8', 'popq %rax']
# >   %t8 = load i64, i64* %local_c.2, align 4
# toR t8
# toR local_c.2
#   - ['movq -24(%rbp), %r9']
# >   %t9 = add i64 0, 57
# toR i64 0
# toR i64 57
# toR t9
#   - ['movq $0, %r10', 'addq $57, %r10']
# >   %t7 = icmp sgt i64 %t8, %t9
# toR t8
# toR t9
# toR t7
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r10, %r9', 'setg %al', 'movq %rax, %r9', 'popq %rax']
# >   %t3 = or i1 %t4, %t7
# toR t4
# toR t7
# toR t3
#   - ['movq %r8, %r8', 'orq %r9, %r8']
# >   br i1 %t3, label %for.0.body, label %for.0.end
# toR t3
#   - ['cmpq $0, %r8', 'je for.0.end']
# >   %t16 = load i64, i64* %local_c.2, align 4
# toR t16
# toR local_c.2
#   - ['movq -24(%rbp), %r9']
# >   %t17 = add i64 0, 45
# toR i64 0
# toR i64 45
# toR t17
#   - ['movq $0, %r8', 'addq $45, %r8']
# >   %t15 = icmp eq i64 %t16, %t17
# toR t16
# toR t17
# toR t15
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r8, %r9', 'sete %al', 'movq %rax, %r8', 'popq %rax']
# >   br i1 %t15, label %if.body1.12, label %if.end1.14
# toR t15
#   - ['cmpq $0, %r8', 'je if.end1.14']
# >   %t19 = add i64 0, 1
# toR i64 0
# toR i64 1
# toR t19
#   - ['movq $0, %r8', 'addq $1, %r8']
# >   %t18 = sub i64 0, %t19
# toR i64 0
# toR t19
# toR t18
#   - ['pushq %rcx', 'movq %r8, %rcx', 'movq $0, %r8', 'subq %rcx, %r8', 'popq %rcx']
# >   store i64 %t18, i64* %local_sign.0, align 4
# toR t18
# toR local_sign.0
#   - ['movq %r8, -8(%rbp)']
# >   br label %if.end1.14
#   - []
# >   %t20 = call i64 @getchar()
# toR t20
#   - ['call getchar@PLT', 'movq %rax, %r8']
# >   store i64 %t20, i64* %local_c.2, align 4
# toR t20
# toR local_c.2
#   - ['movq %r8, -24(%rbp)']
# >   br label %for.0.post
#   - []
# >   br label %for.0.cond
#   - ['jmp for.0.cond']
# >   br label %for.1.cond
#   - []
# >   %t23 = load i64, i64* %local_c.2, align 4
# toR t23
# toR local_c.2
#   - ['movq -24(%rbp), %r8']
# >   %t24 = add i64 0, 48
# toR i64 0
# toR i64 48
# toR t24
#   - ['movq $0, %r9', 'addq $48, %r9']
# >   %t22 = icmp sge i64 %t23, %t24
# toR t23
# toR t24
# toR t22
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setge %al', 'movq %rax, %r10', 'popq %rax']
# >   %t26 = load i64, i64* %local_c.2, align 4
# toR t26
# toR local_c.2
#   - ['movq -24(%rbp), %r8']
# >   %t27 = add i64 0, 57
# toR i64 0
# toR i64 57
# toR t27
#   - ['movq $0, %r9', 'addq $57, %r9']
# >   %t25 = icmp sle i64 %t26, %t27
# toR t26
# toR t27
# toR t25
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setle %al', 'movq %rax, %r8', 'popq %rax']
# >   %t21 = and i1 %t22, %t25
# toR t22
# toR t25
# toR t21
#   - ['movq %r8, %r8', 'andq %r10, %r8']
# >   br i1 %t21, label %for.1.body, label %for.1.end
# toR t21
#   - ['cmpq $0, %r8', 'je for.1.end']
# >   %t31 = load i64, i64* %local_n.1, align 4
# toR t31
# toR local_n.1
#   - ['movq -16(%rbp), %r9']
# >   %t32 = add i64 0, 10
# toR i64 0
# toR i64 10
# toR t32
#   - ['movq $0, %r8', 'addq $10, %r8']
# >   %t30 = mul i64 %t31, %t32
# toR t31
# toR t32
# toR t30
#   - ['pushq %rax', 'pushq %rdx', 'movq %r9, %rax', 'imulq %r8', 'movq %rax, %r9', 'popq %rdx', 'popq %rax']
# >   %t33 = load i64, i64* %local_c.2, align 4
# toR t33
# toR local_c.2
#   - ['movq -24(%rbp), %r8']
# >   %t29 = add i64 %t30, %t33
# toR t30
# toR t33
# toR t29
#   - ['movq %r9, %r9', 'addq %r8, %r9']
# >   %t34 = add i64 0, 48
# toR i64 0
# toR i64 48
# toR t34
#   - ['movq $0, %r8', 'addq $48, %r8']
# >   %t28 = sub i64 %t29, %t34
# toR t29
# toR t34
# toR t28
#   - ['pushq %rcx', 'movq %r8, %rcx', 'movq %r9, %r8', 'subq %rcx, %r8', 'popq %rcx']
# >   store i64 %t28, i64* %local_n.1, align 4
# toR t28
# toR local_n.1
#   - ['movq %r8, -16(%rbp)']
# >   %t35 = call i64 @getchar()
# toR t35
#   - ['call getchar@PLT', 'movq %rax, %r8']
# >   store i64 %t35, i64* %local_c.2, align 4
# toR t35
# toR local_c.2
#   - ['movq %r8, -24(%rbp)']
# >   br label %for.1.post
#   - []
# >   br label %for.1.cond
#   - ['jmp for.1.cond']
# >   %t37 = load i64, i64* %local_n.1, align 4
# toR t37
# toR local_n.1
#   - ['movq -16(%rbp), %r8']
# >   %t38 = load i64, i64* %local_sign.0, align 4
# toR t38
# toR local_sign.0
#   - ['movq -8(%rbp), %r9']
# >   %t36 = mul i64 %t37, %t38
# toR t37
# toR t38
# toR t36
#   - ['pushq %rax', 'pushq %rdx', 'movq %r8, %rax', 'imulq %r9', 'movq %rax, %r8', 'popq %rdx', 'popq %rax']
# >   store i64 %t36, i64* %local_n.1, align 4
# toR t36
# toR local_n.1
#   - ['movq %r8, -16(%rbp)']
# >   %t39 = load i64, i64* %local_n.1, align 4
# toR t39
# toR local_n.1
#   - ['movq -16(%rbp), %r8']
# >   ret i64 %t39
# toR t39
#   - ['movq %r8, %rax', 'jmp main_getInt_end']
# -- ASM: --
# 	.globl main_getInt
# 	main_getInt:
# pushq %rbp
# movq %rsp, %rbp
# subq $24, %rsp
# pushq %r8
# pushq %r9
# pushq %r10
# pushq %r11
# pushq %r12
# pushq %r13
# pushq %r14
# pushq %r15
#   #  %t0 = add i64 0, 1
# movq $0, %r8
# addq $1, %r8
#   #  store i64 %t0, i64* %local_sign.0, align 4
# movq %r8, -8(%rbp)
#   #  %t1 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  store i64 %t1, i64* %local_n.1, align 4
# movq %r8, -16(%rbp)
#   #  %t2 = call i64 @getchar()
# call getchar@PLT
# movq %rax, %r8
#   #  store i64 %t2, i64* %local_c.2, align 4
# movq %r8, -24(%rbp)
#   #  br label %for.0.cond
# 	for.0.cond:
#   #  %t5 = load i64, i64* %local_c.2, align 4
# movq -24(%rbp), %r8
#   #  %t6 = add i64 0, 48
# movq $0, %r9
# addq $48, %r9
#   #  %t4 = icmp slt i64 %t5, %t6
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setl %al
# movq %rax, %r8
# popq %rax
#   #  %t8 = load i64, i64* %local_c.2, align 4
# movq -24(%rbp), %r9
#   #  %t9 = add i64 0, 57
# movq $0, %r10
# addq $57, %r10
#   #  %t7 = icmp sgt i64 %t8, %t9
# pushq %rax
# movq $0, %rax
# cmpq %r10, %r9
# setg %al
# movq %rax, %r9
# popq %rax
#   #  %t3 = or i1 %t4, %t7
# movq %r8, %r8
# orq %r9, %r8
#   #  br i1 %t3, label %for.0.body, label %for.0.end
# cmpq $0, %r8
# je for.0.end
# 	for.0.body:
#   #  %t16 = load i64, i64* %local_c.2, align 4
# movq -24(%rbp), %r9
#   #  %t17 = add i64 0, 45
# movq $0, %r8
# addq $45, %r8
#   #  %t15 = icmp eq i64 %t16, %t17
# pushq %rax
# movq $0, %rax
# cmpq %r8, %r9
# sete %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t15, label %if.body1.12, label %if.end1.14
# cmpq $0, %r8
# je if.end1.14
# 	if.body1.12:
#   #  %t19 = add i64 0, 1
# movq $0, %r8
# addq $1, %r8
#   #  %t18 = sub i64 0, %t19
# pushq %rcx
# movq %r8, %rcx
# movq $0, %r8
# subq %rcx, %r8
# popq %rcx
#   #  store i64 %t18, i64* %local_sign.0, align 4
# movq %r8, -8(%rbp)
#   #  br label %if.end1.14
# 	if.end1.14:
#   #  %t20 = call i64 @getchar()
# call getchar@PLT
# movq %rax, %r8
#   #  store i64 %t20, i64* %local_c.2, align 4
# movq %r8, -24(%rbp)
#   #  br label %for.0.post
# 	for.0.post:
#   #  br label %for.0.cond
# jmp for.0.cond
# 	for.0.end:
#   #  br label %for.1.cond
# 	for.1.cond:
#   #  %t23 = load i64, i64* %local_c.2, align 4
# movq -24(%rbp), %r8
#   #  %t24 = add i64 0, 48
# movq $0, %r9
# addq $48, %r9
#   #  %t22 = icmp sge i64 %t23, %t24
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setge %al
# movq %rax, %r10
# popq %rax
#   #  %t26 = load i64, i64* %local_c.2, align 4
# movq -24(%rbp), %r8
#   #  %t27 = add i64 0, 57
# movq $0, %r9
# addq $57, %r9
#   #  %t25 = icmp sle i64 %t26, %t27
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setle %al
# movq %rax, %r8
# popq %rax
#   #  %t21 = and i1 %t22, %t25
# movq %r8, %r8
# andq %r10, %r8
#   #  br i1 %t21, label %for.1.body, label %for.1.end
# cmpq $0, %r8
# je for.1.end
# 	for.1.body:
#   #  %t31 = load i64, i64* %local_n.1, align 4
# movq -16(%rbp), %r9
#   #  %t32 = add i64 0, 10
# movq $0, %r8
# addq $10, %r8
#   #  %t30 = mul i64 %t31, %t32
# pushq %rax
# pushq %rdx
# movq %r9, %rax
# imulq %r8
# movq %rax, %r9
# popq %rdx
# popq %rax
#   #  %t33 = load i64, i64* %local_c.2, align 4
# movq -24(%rbp), %r8
#   #  %t29 = add i64 %t30, %t33
# movq %r9, %r9
# addq %r8, %r9
#   #  %t34 = add i64 0, 48
# movq $0, %r8
# addq $48, %r8
#   #  %t28 = sub i64 %t29, %t34
# pushq %rcx
# movq %r8, %rcx
# movq %r9, %r8
# subq %rcx, %r8
# popq %rcx
#   #  store i64 %t28, i64* %local_n.1, align 4
# movq %r8, -16(%rbp)
#   #  %t35 = call i64 @getchar()
# call getchar@PLT
# movq %rax, %r8
#   #  store i64 %t35, i64* %local_c.2, align 4
# movq %r8, -24(%rbp)
#   #  br label %for.1.post
# 	for.1.post:
#   #  br label %for.1.cond
# jmp for.1.cond
# 	for.1.end:
#   #  %t37 = load i64, i64* %local_n.1, align 4
# movq -16(%rbp), %r8
#   #  %t38 = load i64, i64* %local_sign.0, align 4
# movq -8(%rbp), %r9
#   #  %t36 = mul i64 %t37, %t38
# pushq %rax
# pushq %rdx
# movq %r8, %rax
# imulq %r9
# movq %rax, %r8
# popq %rdx
# popq %rax
#   #  store i64 %t36, i64* %local_n.1, align 4
# movq %r8, -16(%rbp)
#   #  %t39 = load i64, i64* %local_n.1, align 4
# movq -16(%rbp), %r8
#   #  ret i64 %t39
# movq %r8, %rax
# jmp main_getInt_end
# 	main_getInt_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
# codeGenForFunc main_inString
# {'for.2.cond': 8, 'for.2.body': 12, 'if.body4.49': 16, 'if.end4.51': 19, 'for.2.post': 20, 'for.2.end': 21}
#   br label %for.2.cond
#   br i1 %t44, label %for.2.body, label %for.2.end
#   br i1 %t52, label %if.body4.49, label %if.end4.51
#   br label %if.end4.51
#   br label %for.2.post
#   br label %for.2.cond
# 0 [[1], {'local_c.3.arg0'}, set()]
# 1 [[2], {'local_s.4.arg1'}, set()]
# 2 [[3], set(), {'t40'}]
# 3 [[4], set(), {'t41'}]
# 4 [[5], {'t41', 't40'}, {'t42'}]
# 5 [[6], {'t42'}, {'t43'}]
# 6 [[7], {'t43'}, set()]
# 7 [[8], set(), set()]
# 8 [[9], set(), {'t45'}]
# 9 [[10], set(), {'t46'}]
# 10 [[11], {'t46', 't45'}, {'t44'}]
# 11 [[21, 12], {'t44'}, set()]
# 12 [[13], set(), {'t53'}]
# 13 [[14], set(), {'t54'}]
# 14 [[15], {'t53', 't54'}, {'t52'}]
# 15 [[19, 16], {'t52'}, set()]
# 16 [[17], set(), {'t55'}]
# 17 [[18], {'t55'}, set()]
# 18 [[19], set(), set()]
# 19 [[20], set(), set()]
# 20 [[8], set(), set()]
# 21 [[22], set(), {'t56'}]
# 22 [[], {'t56'}, set()]
# done
# count 3
# 0 {} {local_c.3.arg0} | {local_s.4.arg1, local_c.3.arg0} {local_s.4.arg1}
# 1 {} {local_s.4.arg1} | {local_s.4.arg1} {}
# 2 {t40} {} | {} {t40}
# 3 {t41} {} | {t40} {t41, t40}
# 4 {t42} {t41, t40} | {t41, t40} {t42}
# 5 {t43} {t42} | {t42} {t43}
# 6 {} {t43} | {t43} {}
# 7 {} {} | {} {}
# 8 {t45} {} | {} {t45}
# 9 {t46} {} | {t45} {t46, t45}
# 10 {t44} {t46, t45} | {t46, t45} {t44}
# 11 {} {t44} | {t44} {}
# 12 {t53} {} | {} {t53}
# 13 {t54} {} | {t53} {t53, t54}
# 14 {t52} {t53, t54} | {t53, t54} {t52}
# 15 {} {t52} | {t52} {}
# 16 {t55} {} | {} {t55}
# 17 {} {t55} | {t55} {}
# 18 {} {} | {} {}
# 19 {} {} | {} {}
# 20 {} {} | {} {}
# 21 {t56} {} | {} {t56}
# 22 {} {t56} | {t56} {}
# {'local_c.3': 8, 'local_s.4': 8, 'local_cur.5': 8}
# 24
# {'t46', 't41', 't40', 't53', 't56', 't54', 't45', 't43', 'local_s.4.arg1', 't55', 't44', 't52', 't42', 'local_c.3.arg0'}
# add t41 t40
# add t46 t45
# add t54 t53
# coloring {'local_c.3.arg0': 0, 't42': 0, 't52': 0, 't44': 0, 't55': 0, 'local_s.4.arg1': 0, 't43': 0, 't45': 0, 't54': 0, 't56': 0, 't53': 1, 't40': 0, 't41': 1, 't46': 1}
# single nodes: {'t56', 't43', 't55', 'local_s.4.arg1', 't44', 't52', 't42', 'local_c.3.arg0'}
# color needed: 2
# depth {'local_c.3': 8, 'local_s.4': 16, 'local_cur.5': 24}
# >   store i64 %local_c.3.arg0, i64* %local_c.3, align 4
# toR local_c.3.arg0
# toR local_c.3
#   - ['movq %rdi, -8(%rbp)']
# >   store i64* %local_s.4.arg1, i64** %local_s.4, align 8
# toR local_s.4.arg1
# toR local_s.4
#   - ['movq %rsi, -16(%rbp)']
# >   %t40 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t40
#   - ['movq $0, %r8', 'addq $0, %r8']
# >   %t41 = load i64*, i64** %local_s.4, align 4
# toR t41
# toR local_s.4
#   - ['movq -16(%rbp), %r9']
# >   %t42 = getelementptr inbounds i64, i64* %t41, i64 %t40
# toR t41
# toR t40
# toR t42
#   - ['leaq (%r9,%r8,8), %r8']
# >   %t43 = load i64, i64* %t42, align 4
# toR t43
# toR t42
#   - ['movq (%r8), %r8']
# >   store i64 %t43, i64* %local_cur.5, align 4
# toR t43
# toR local_cur.5
#   - ['movq %r8, -24(%rbp)']
# >   br label %for.2.cond
#   - []
# >   %t45 = load i64, i64* %local_cur.5, align 4
# toR t45
# toR local_cur.5
#   - ['movq -24(%rbp), %r8']
# >   %t46 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t46
#   - ['movq $0, %r9', 'addq $0, %r9']
# >   %t44 = icmp ne i64 %t45, %t46
# toR t45
# toR t46
# toR t44
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setne %al', 'movq %rax, %r8', 'popq %rax']
# >   br i1 %t44, label %for.2.body, label %for.2.end
# toR t44
#   - ['cmpq $0, %r8', 'je for.2.end']
# >   %t53 = load i64, i64* %local_cur.5, align 4
# toR t53
# toR local_cur.5
#   - ['movq -24(%rbp), %r9']
# >   %t54 = load i64, i64* %local_c.3, align 4
# toR t54
# toR local_c.3
#   - ['movq -8(%rbp), %r8']
# >   %t52 = icmp eq i64 %t53, %t54
# toR t53
# toR t54
# toR t52
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r8, %r9', 'sete %al', 'movq %rax, %r8', 'popq %rax']
# >   br i1 %t52, label %if.body4.49, label %if.end4.51
# toR t52
#   - ['cmpq $0, %r8', 'je if.end4.51']
# >   %t55 = add i64 0, 1
# toR i64 0
# toR i64 1
# toR t55
#   - ['movq $0, %r8', 'addq $1, %r8']
# >   ret i64 %t55
# toR t55
#   - ['movq %r8, %rax', 'jmp main_inString_end']
# >   br label %if.end4.51
#   - []
# >   br label %for.2.post
#   - []
# >   br label %for.2.cond
#   - ['jmp for.2.cond']
# >   %t56 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t56
#   - ['movq $0, %r8', 'addq $0, %r8']
# >   ret i64 %t56
# toR t56
#   - ['movq %r8, %rax', 'jmp main_inString_end']
# -- ASM: --
# 	.globl main_inString
# 	main_inString:
# pushq %rbp
# movq %rsp, %rbp
# subq $24, %rsp
# pushq %r8
# pushq %r9
# pushq %r10
# pushq %r11
# pushq %r12
# pushq %r13
# pushq %r14
# pushq %r15
#   #  store i64 %local_c.3.arg0, i64* %local_c.3, align 4
# movq %rdi, -8(%rbp)
#   #  store i64* %local_s.4.arg1, i64** %local_s.4, align 8
# movq %rsi, -16(%rbp)
#   #  %t40 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  %t41 = load i64*, i64** %local_s.4, align 4
# movq -16(%rbp), %r9
#   #  %t42 = getelementptr inbounds i64, i64* %t41, i64 %t40
# leaq (%r9,%r8,8), %r8
#   #  %t43 = load i64, i64* %t42, align 4
# movq (%r8), %r8
#   #  store i64 %t43, i64* %local_cur.5, align 4
# movq %r8, -24(%rbp)
#   #  br label %for.2.cond
# 	for.2.cond:
#   #  %t45 = load i64, i64* %local_cur.5, align 4
# movq -24(%rbp), %r8
#   #  %t46 = add i64 0, 0
# movq $0, %r9
# addq $0, %r9
#   #  %t44 = icmp ne i64 %t45, %t46
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setne %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t44, label %for.2.body, label %for.2.end
# cmpq $0, %r8
# je for.2.end
# 	for.2.body:
#   #  %t53 = load i64, i64* %local_cur.5, align 4
# movq -24(%rbp), %r9
#   #  %t54 = load i64, i64* %local_c.3, align 4
# movq -8(%rbp), %r8
#   #  %t52 = icmp eq i64 %t53, %t54
# pushq %rax
# movq $0, %rax
# cmpq %r8, %r9
# sete %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t52, label %if.body4.49, label %if.end4.51
# cmpq $0, %r8
# je if.end4.51
# 	if.body4.49:
#   #  %t55 = add i64 0, 1
# movq $0, %r8
# addq $1, %r8
#   #  ret i64 %t55
# movq %r8, %rax
# jmp main_inString_end
#   #  br label %if.end4.51
# 	if.end4.51:
#   #  br label %for.2.post
# 	for.2.post:
#   #  br label %for.2.cond
# jmp for.2.cond
# 	for.2.end:
#   #  %t56 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  ret i64 %t56
# movq %r8, %rax
# jmp main_inString_end
# 	main_inString_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
# codeGenForFunc main_getString
# {'for.3.cond': 12, 'for.3.body': 22, 'for.3.post': 33, 'for.3.end': 34}
#   br label %for.3.cond
#   br i1 %t63, label %for.3.body, label %for.3.end
#   br label %for.3.post
#   br label %for.3.cond
# 0 [[1], {'local_maxLen.6.arg0'}, set()]
# 1 [[2], {'local_stop.7.arg1'}, set()]
# 2 [[3], set(), {'t57'}]
# 3 [[4], {'t57'}, {'t59'}]
# 4 [[5], {'t59'}, {'t60'}]
# 5 [[6], {'t60'}, {'t58'}]
# 6 [[7], {'t58'}, set()]
# 7 [[8], set(), {'t61'}]
# 8 [[9], {'t61'}, set()]
# 9 [[10], set(), {'t62'}]
# 10 [[11], {'t62'}, set()]
# 11 [[12], set(), set()]
# 12 [[13], set(), {'t65'}]
# 13 [[14], set(), {'t66'}]
# 14 [[15], {'t66', 't65'}, {'t67'}]
# 15 [[16], set(), {'t68'}]
# 16 [[17], {'t68', 't67'}, {'t64'}]
# 17 [[18], set(), {'t70'}]
# 18 [[19], set(), {'t71'}]
# 19 [[20], {'t71', 't70'}, {'t69'}]
# 20 [[21], {'t69', 't64'}, {'t63'}]
# 21 [[34, 22], {'t63'}, set()]
# 22 [[23], set(), {'t72'}]
# 23 [[24], set(), {'t73'}]
# 24 [[25], set(), {'t74'}]
# 25 [[26], {'t74', 't73'}, {'t75'}]
# 26 [[27], {'t72', 't75'}, set()]
# 27 [[28], set(), {'t76'}]
# 28 [[29], {'t76'}, {'t77'}]
# 29 [[30], {'t77'}, set()]
# 30 [[31], set(), {'t78'}]
# 31 [[32], {'t78'}, set()]
# 32 [[33], set(), set()]
# 33 [[12], set(), set()]
# 34 [[35], set(), {'t79'}]
# 35 [[36], set(), {'t80'}]
# 36 [[37], set(), {'t81'}]
# 37 [[38], {'t81', 't80'}, {'t82'}]
# 38 [[39], {'t79', 't82'}, set()]
# 39 [[40], set(), {'t83'}]
# 40 [[], {'t83'}, set()]
# done
# count 5
# 0 {} {local_maxLen.6.arg0} | {local_stop.7.arg1, local_maxLen.6.arg0} {local_stop.7.arg1}
# 1 {} {local_stop.7.arg1} | {local_stop.7.arg1} {}
# 2 {t57} {} | {} {t57}
# 3 {t59} {t57} | {t57} {t59}
# 4 {t60} {t59} | {t59} {t60}
# 5 {t58} {t60} | {t60} {t58}
# 6 {} {t58} | {t58} {}
# 7 {t61} {} | {} {t61}
# 8 {} {t61} | {t61} {}
# 9 {t62} {} | {} {t62}
# 10 {} {t62} | {t62} {}
# 11 {} {} | {} {}
# 12 {t65} {} | {} {t65}
# 13 {t66} {} | {t65} {t66, t65}
# 14 {t67} {t66, t65} | {t66, t65} {t67}
# 15 {t68} {} | {t67} {t68, t67}
# 16 {t64} {t68, t67} | {t68, t67} {t64}
# 17 {t70} {} | {t64} {t70, t64}
# 18 {t71} {} | {t70, t64} {t71, t70, t64}
# 19 {t69} {t71, t70} | {t71, t70, t64} {t69, t64}
# 20 {t63} {t69, t64} | {t69, t64} {t63}
# 21 {} {t63} | {t63} {}
# 22 {t72} {} | {} {t72}
# 23 {t73} {} | {t72} {t72, t73}
# 24 {t74} {} | {t72, t73} {t74, t72, t73}
# 25 {t75} {t74, t73} | {t74, t72, t73} {t72, t75}
# 26 {} {t72, t75} | {t72, t75} {}
# 27 {t76} {} | {} {t76}
# 28 {t77} {t76} | {t76} {t77}
# 29 {} {t77} | {t77} {}
# 30 {t78} {} | {} {t78}
# 31 {} {t78} | {t78} {}
# 32 {} {} | {} {}
# 33 {} {} | {} {}
# 34 {t79} {} | {} {t79}
# 35 {t80} {} | {t79} {t79, t80}
# 36 {t81} {} | {t79, t80} {t79, t81, t80}
# 37 {t82} {t81, t80} | {t79, t81, t80} {t79, t82}
# 38 {} {t79, t82} | {t79, t82} {}
# 39 {t83} {} | {} {t83}
# 40 {} {t83} | {t83} {}
# {'local_maxLen.6': 8, 'local_stop.7': 8, 'local_s.8': 8, 'local_i.9': 8, 'local_c.10': 8}
# 40
# {'t60', 't62', 't74', 't68', 't65', 'local_maxLen.6.arg0', 't58', 't61', 't81', 't82', 't66', 't64', 't72', 't59', 't67', 't57', 't71', 't75', 't77', 't79', 't83', 't69', 'local_stop.7.arg1', 't80', 't78', 't63', 't73', 't70', 't76'}
# add t66 t65
# add t68 t67
# add t70 t64
# add t71 t70
# add t71 t64
# add t69 t64
# add t73 t72
# add t74 t72
# add t74 t73
# add t75 t72
# add t80 t79
# add t81 t79
# add t81 t80
# add t82 t79
# coloring {'t76': 0, 't70': 0, 't73': 0, 't63': 0, 't78': 0, 't80': 0, 'local_stop.7.arg1': 0, 't69': 0, 't83': 0, 't79': 1, 't77': 0, 't75': 0, 't71': 1, 't57': 0, 't67': 0, 't59': 0, 't72': 1, 't64': 2, 't66': 0, 't82': 0, 't81': 2, 't61': 0, 't58': 0, 'local_maxLen.6.arg0': 0, 't65': 1, 't68': 1, 't74': 2, 't62': 0, 't60': 0}
# single nodes: {'t60', 't62', 't59', 't77', 't57', 't83', 'local_stop.7.arg1', 'local_maxLen.6.arg0', 't78', 't63', 't58', 't76', 't61'}
# color needed: 3
# depth {'local_maxLen.6': 8, 'local_stop.7': 16, 'local_s.8': 24, 'local_i.9': 32, 'local_c.10': 40}
# >   store i64 %local_maxLen.6.arg0, i64* %local_maxLen.6, align 4
# toR local_maxLen.6.arg0
# toR local_maxLen.6
#   - ['movq %rdi, -8(%rbp)']
# >   store i64* %local_stop.7.arg1, i64** %local_stop.7, align 8
# toR local_stop.7.arg1
# toR local_stop.7
#   - ['movq %rsi, -16(%rbp)']
# >   %t57 = load i64, i64* %local_maxLen.6, align 4
# toR t57
# toR local_maxLen.6
#   - ['movq -8(%rbp), %r8']
# >   %t59 = mul i64 %t57, 8
# toR t57
# toR i64 8
# toR t59
#   - ['pushq %rax', 'pushq %rdx', 'pushq %rcx', 'movq %r8, %rax', 'movq $8, %rcx', 'imulq %rcx', 'movq %rax, %r8', 'popq %rcx', 'popq %rdx', 'popq %rax']
# >   %t60 = call noalias i8* @malloc(i64 %t59)
# toR t60
# toR t59
#   - ['movq %r8, %rdi', 'call malloc@PLT', 'movq %rax, %r8']
# >   %t58 = bitcast i8* %t60 to i64*
# toR t60
# toR t58
#   - ['movq %r8, %r8']
# >   store i64* %t58, i64** %local_s.8, align 8
# toR t58
# toR local_s.8
#   - ['movq %r8, -24(%rbp)']
# >   %t61 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t61
#   - ['movq $0, %r8', 'addq $0, %r8']
# >   store i64 %t61, i64* %local_i.9, align 4
# toR t61
# toR local_i.9
#   - ['movq %r8, -32(%rbp)']
# >   %t62 = call i64 @getchar()
# toR t62
#   - ['call getchar@PLT', 'movq %rax, %r8']
# >   store i64 %t62, i64* %local_c.10, align 4
# toR t62
# toR local_c.10
#   - ['movq %r8, -40(%rbp)']
# >   br label %for.3.cond
#   - []
# >   %t65 = load i64, i64* %local_c.10, align 4
# toR t65
# toR local_c.10
#   - ['movq -40(%rbp), %r9']
# >   %t66 = load i64*, i64** %local_stop.7, align 4
# toR t66
# toR local_stop.7
#   - ['movq -16(%rbp), %r8']
# >   %t67 = call i64 @main_inString(i64 %t65, i64* %t66)
# toR t67
# toR t65
# toR t66
#   - ['movq %r9, %rdi', 'movq %r8, %rsi', 'call main_inString@PLT', 'movq %rax, %r8']
# >   %t68 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t68
#   - ['movq $0, %r9', 'addq $0, %r9']
# >   %t64 = icmp eq i64 %t67, %t68
# toR t67
# toR t68
# toR t64
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'sete %al', 'movq %rax, %r10', 'popq %rax']
# >   %t70 = load i64, i64* %local_i.9, align 4
# toR t70
# toR local_i.9
#   - ['movq -32(%rbp), %r8']
# >   %t71 = load i64, i64* %local_maxLen.6, align 4
# toR t71
# toR local_maxLen.6
#   - ['movq -8(%rbp), %r9']
# >   %t69 = icmp slt i64 %t70, %t71
# toR t70
# toR t71
# toR t69
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setl %al', 'movq %rax, %r8', 'popq %rax']
# >   %t63 = and i1 %t64, %t69
# toR t64
# toR t69
# toR t63
#   - ['movq %r8, %r8', 'andq %r10, %r8']
# >   br i1 %t63, label %for.3.body, label %for.3.end
# toR t63
#   - ['cmpq $0, %r8', 'je for.3.end']
# >   %t72 = load i64, i64* %local_c.10, align 4
# toR t72
# toR local_c.10
#   - ['movq -40(%rbp), %r9']
# >   %t73 = load i64, i64* %local_i.9, align 4
# toR t73
# toR local_i.9
#   - ['movq -32(%rbp), %r8']
# >   %t74 = load i64*, i64** %local_s.8, align 4
# toR t74
# toR local_s.8
#   - ['movq -24(%rbp), %r10']
# >   %t75 = getelementptr inbounds i64, i64* %t74, i64 %t73
# toR t74
# toR t73
# toR t75
#   - ['leaq (%r10,%r8,8), %r8']
# >   store i64 %t72, i64* %t75, align 4
# toR t72
# toR t75
#   - ['movq %r9, (%r8)']
# >   %t76 = load i64, i64* %local_i.9, align 4
# toR t76
# toR local_i.9
#   - ['movq -32(%rbp), %r8']
# >   %t77 = add i64 %t76, 1
# toR t76
# toR i64 1
# toR t77
#   - ['movq %r8, %r8', 'addq $1, %r8']
# >   store i64 %t77, i64* %local_i.9, align 4
# toR t77
# toR local_i.9
#   - ['movq %r8, -32(%rbp)']
# >   %t78 = call i64 @getchar()
# toR t78
#   - ['call getchar@PLT', 'movq %rax, %r8']
# >   store i64 %t78, i64* %local_c.10, align 4
# toR t78
# toR local_c.10
#   - ['movq %r8, -40(%rbp)']
# >   br label %for.3.post
#   - []
# >   br label %for.3.cond
#   - ['jmp for.3.cond']
# >   %t79 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t79
#   - ['movq $0, %r9', 'addq $0, %r9']
# >   %t80 = load i64, i64* %local_i.9, align 4
# toR t80
# toR local_i.9
#   - ['movq -32(%rbp), %r8']
# >   %t81 = load i64*, i64** %local_s.8, align 4
# toR t81
# toR local_s.8
#   - ['movq -24(%rbp), %r10']
# >   %t82 = getelementptr inbounds i64, i64* %t81, i64 %t80
# toR t81
# toR t80
# toR t82
#   - ['leaq (%r10,%r8,8), %r8']
# >   store i64 %t79, i64* %t82, align 4
# toR t79
# toR t82
#   - ['movq %r9, (%r8)']
# >   %t83 = load i64*, i64** %local_s.8, align 4
# toR t83
# toR local_s.8
#   - ['movq -24(%rbp), %r8']
# >   ret i64* %t83
# toR t83
#   - ['movq %r8, %rax', 'jmp main_getString_end']
# -- ASM: --
# 	.globl main_getString
# 	main_getString:
# pushq %rbp
# movq %rsp, %rbp
# subq $40, %rsp
# pushq %r8
# pushq %r9
# pushq %r10
# pushq %r11
# pushq %r12
# pushq %r13
# pushq %r14
# pushq %r15
#   #  store i64 %local_maxLen.6.arg0, i64* %local_maxLen.6, align 4
# movq %rdi, -8(%rbp)
#   #  store i64* %local_stop.7.arg1, i64** %local_stop.7, align 8
# movq %rsi, -16(%rbp)
#   #  %t57 = load i64, i64* %local_maxLen.6, align 4
# movq -8(%rbp), %r8
#   #  %t59 = mul i64 %t57, 8
# pushq %rax
# pushq %rdx
# pushq %rcx
# movq %r8, %rax
# movq $8, %rcx
# imulq %rcx
# movq %rax, %r8
# popq %rcx
# popq %rdx
# popq %rax
#   #  %t60 = call noalias i8* @malloc(i64 %t59)
# movq %r8, %rdi
# call malloc@PLT
# movq %rax, %r8
#   #  %t58 = bitcast i8* %t60 to i64*
# movq %r8, %r8
#   #  store i64* %t58, i64** %local_s.8, align 8
# movq %r8, -24(%rbp)
#   #  %t61 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  store i64 %t61, i64* %local_i.9, align 4
# movq %r8, -32(%rbp)
#   #  %t62 = call i64 @getchar()
# call getchar@PLT
# movq %rax, %r8
#   #  store i64 %t62, i64* %local_c.10, align 4
# movq %r8, -40(%rbp)
#   #  br label %for.3.cond
# 	for.3.cond:
#   #  %t65 = load i64, i64* %local_c.10, align 4
# movq -40(%rbp), %r9
#   #  %t66 = load i64*, i64** %local_stop.7, align 4
# movq -16(%rbp), %r8
#   #  %t67 = call i64 @main_inString(i64 %t65, i64* %t66)
# movq %r9, %rdi
# movq %r8, %rsi
# call main_inString@PLT
# movq %rax, %r8
#   #  %t68 = add i64 0, 0
# movq $0, %r9
# addq $0, %r9
#   #  %t64 = icmp eq i64 %t67, %t68
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# sete %al
# movq %rax, %r10
# popq %rax
#   #  %t70 = load i64, i64* %local_i.9, align 4
# movq -32(%rbp), %r8
#   #  %t71 = load i64, i64* %local_maxLen.6, align 4
# movq -8(%rbp), %r9
#   #  %t69 = icmp slt i64 %t70, %t71
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setl %al
# movq %rax, %r8
# popq %rax
#   #  %t63 = and i1 %t64, %t69
# movq %r8, %r8
# andq %r10, %r8
#   #  br i1 %t63, label %for.3.body, label %for.3.end
# cmpq $0, %r8
# je for.3.end
# 	for.3.body:
#   #  %t72 = load i64, i64* %local_c.10, align 4
# movq -40(%rbp), %r9
#   #  %t73 = load i64, i64* %local_i.9, align 4
# movq -32(%rbp), %r8
#   #  %t74 = load i64*, i64** %local_s.8, align 4
# movq -24(%rbp), %r10
#   #  %t75 = getelementptr inbounds i64, i64* %t74, i64 %t73
# leaq (%r10,%r8,8), %r8
#   #  store i64 %t72, i64* %t75, align 4
# movq %r9, (%r8)
#   #  %t76 = load i64, i64* %local_i.9, align 4
# movq -32(%rbp), %r8
#   #  %t77 = add i64 %t76, 1
# movq %r8, %r8
# addq $1, %r8
#   #  store i64 %t77, i64* %local_i.9, align 4
# movq %r8, -32(%rbp)
#   #  %t78 = call i64 @getchar()
# call getchar@PLT
# movq %rax, %r8
#   #  store i64 %t78, i64* %local_c.10, align 4
# movq %r8, -40(%rbp)
#   #  br label %for.3.post
# 	for.3.post:
#   #  br label %for.3.cond
# jmp for.3.cond
# 	for.3.end:
#   #  %t79 = add i64 0, 0
# movq $0, %r9
# addq $0, %r9
#   #  %t80 = load i64, i64* %local_i.9, align 4
# movq -32(%rbp), %r8
#   #  %t81 = load i64*, i64** %local_s.8, align 4
# movq -24(%rbp), %r10
#   #  %t82 = getelementptr inbounds i64, i64* %t81, i64 %t80
# leaq (%r10,%r8,8), %r8
#   #  store i64 %t79, i64* %t82, align 4
# movq %r9, (%r8)
#   #  %t83 = load i64*, i64** %local_s.8, align 4
# movq -24(%rbp), %r8
#   #  ret i64* %t83
# movq %r8, %rax
# jmp main_getString_end
# 	main_getString_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
# codeGenForFunc main_putInt
# {'if.body6.86': 5, 'if.end6.88': 11, 'if.body7.98': 17, 'if.end7.100': 22}
#   br i1 %t89, label %if.body6.86, label %if.end6.88
#   br label %if.end6.88
#   br i1 %t101, label %if.body7.98, label %if.end7.100
#   br label %if.end7.100
# 0 [[1], {'local_n.11.arg0'}, set()]
# 1 [[2], set(), {'t90'}]
# 2 [[3], set(), {'t91'}]
# 3 [[4], {'t91', 't90'}, {'t89'}]
# 4 [[11, 5], {'t89'}, set()]
# 5 [[6], set(), {'t92'}]
# 6 [[7], {'t92'}, {'t93'}]
# 7 [[8], set(), {'t95'}]
# 8 [[9], {'t95'}, {'t94'}]
# 9 [[10], {'t94'}, set()]
# 10 [[11], set(), set()]
# 11 [[12], set(), {'t103'}]
# 12 [[13], set(), {'t104'}]
# 13 [[14], {'t104', 't103'}, {'t102'}]
# 14 [[15], set(), {'t105'}]
# 15 [[16], {'t102', 't105'}, {'t101'}]
# 16 [[22, 17], {'t101'}, set()]
# 17 [[18], set(), {'t107'}]
# 18 [[19], set(), {'t108'}]
# 19 [[20], {'t108', 't107'}, {'t106'}]
# 20 [[21], {'t106'}, set()]
# 21 [[22], set(), set()]
# 22 [[23], set(), {'t111'}]
# 23 [[24], set(), {'t112'}]
# 24 [[25], {'t111', 't112'}, {'t110'}]
# 25 [[26], set(), {'t113'}]
# 26 [[27], {'t113', 't110'}, {'t109'}]
# 27 [[28], {'t109'}, {'t114'}]
# 28 [[], set(), set()]
# done
# count 3
# 0 {} {local_n.11.arg0} | {local_n.11.arg0} {}
# 1 {t90} {} | {} {t90}
# 2 {t91} {} | {t90} {t91, t90}
# 3 {t89} {t91, t90} | {t91, t90} {t89}
# 4 {} {t89} | {t89} {}
# 5 {t92} {} | {} {t92}
# 6 {t93} {t92} | {t92} {}
# 7 {t95} {} | {} {t95}
# 8 {t94} {t95} | {t95} {t94}
# 9 {} {t94} | {t94} {}
# 10 {} {} | {} {}
# 11 {t103} {} | {} {t103}
# 12 {t104} {} | {t103} {t104, t103}
# 13 {t102} {t104, t103} | {t104, t103} {t102}
# 14 {t105} {} | {t102} {t102, t105}
# 15 {t101} {t102, t105} | {t102, t105} {t101}
# 16 {} {t101} | {t101} {}
# 17 {t107} {} | {} {t107}
# 18 {t108} {} | {t107} {t108, t107}
# 19 {t106} {t108, t107} | {t108, t107} {t106}
# 20 {} {t106} | {t106} {}
# 21 {} {} | {} {}
# 22 {t111} {} | {} {t111}
# 23 {t112} {} | {t111} {t111, t112}
# 24 {t110} {t111, t112} | {t111, t112} {t110}
# 25 {t113} {} | {t110} {t113, t110}
# 26 {t109} {t113, t110} | {t113, t110} {t109}
# 27 {t114} {t109} | {t109} {}
# 28 {} {} | {} {}
# {'local_n.11': 8}
# 8
# {'t104', 't112', 't107', 't105', 'local_n.11.arg0', 't113', 't110', 't91', 't89', 't108', 't90', 't114', 't92', 't103', 't101', 't94', 't95', 't111', 't93', 't109', 't102', 't106'}
# add t91 t90
# add t104 t103
# add t105 t102
# add t108 t107
# add t112 t111
# add t113 t110
# coloring {'t106': 0, 't102': 0, 't109': 0, 't93': 0, 't111': 0, 't95': 0, 't94': 0, 't101': 0, 't103': 0, 't92': 0, 't114': 0, 't90': 0, 't108': 0, 't89': 0, 't91': 1, 't110': 0, 't113': 1, 'local_n.11.arg0': 0, 't105': 1, 't107': 1, 't112': 1, 't104': 1}
# single nodes: {'t114', 't92', 't101', 't94', 't95', 't93', 'local_n.11.arg0', 't109', 't106', 't89'}
# color needed: 2
# depth {'local_n.11': 8}
# >   store i64 %local_n.11.arg0, i64* %local_n.11, align 4
# toR local_n.11.arg0
# toR local_n.11
#   - ['movq %rdi, -8(%rbp)']
# >   %t90 = load i64, i64* %local_n.11, align 4
# toR t90
# toR local_n.11
#   - ['movq -8(%rbp), %r8']
# >   %t91 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t91
#   - ['movq $0, %r9', 'addq $0, %r9']
# >   %t89 = icmp slt i64 %t90, %t91
# toR t90
# toR t91
# toR t89
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setl %al', 'movq %rax, %r8', 'popq %rax']
# >   br i1 %t89, label %if.body6.86, label %if.end6.88
# toR t89
#   - ['cmpq $0, %r8', 'je if.end6.88']
# >   %t92 = add i64 0, 45
# toR i64 0
# toR i64 45
# toR t92
#   - ['movq $0, %r8', 'addq $45, %r8']
# >   %t93 = call i64 @putchar(i64 %t92)
# toR t93
# toR t92
#   - ['movq %r8, %rdi', 'call putchar@PLT', 'movq %rax, %r8']
# >   %t95 = load i64, i64* %local_n.11, align 4
# toR t95
# toR local_n.11
#   - ['movq -8(%rbp), %r8']
# >   %t94 = sub i64 0, %t95
# toR i64 0
# toR t95
# toR t94
#   - ['pushq %rcx', 'movq %r8, %rcx', 'movq $0, %r8', 'subq %rcx, %r8', 'popq %rcx']
# >   store i64 %t94, i64* %local_n.11, align 4
# toR t94
# toR local_n.11
#   - ['movq %r8, -8(%rbp)']
# >   br label %if.end6.88
#   - []
# >   %t103 = load i64, i64* %local_n.11, align 4
# toR t103
# toR local_n.11
#   - ['movq -8(%rbp), %r8']
# >   %t104 = add i64 0, 10
# toR i64 0
# toR i64 10
# toR t104
#   - ['movq $0, %r9', 'addq $10, %r9']
# >   %t102 = sdiv i64 %t103, %t104
# toR t103
# toR t104
# toR t102
#   - ['pushq %rax', 'pushq %rdx', 'movq %r8, %rax', 'cqto', 'idivq %r9', 'movq %rax, %r8', 'popq %rdx', 'popq %rax']
# >   %t105 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t105
#   - ['movq $0, %r9', 'addq $0, %r9']
# >   %t101 = icmp ne i64 %t102, %t105
# toR t102
# toR t105
# toR t101
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setne %al', 'movq %rax, %r8', 'popq %rax']
# >   br i1 %t101, label %if.body7.98, label %if.end7.100
# toR t101
#   - ['cmpq $0, %r8', 'je if.end7.100']
# >   %t107 = load i64, i64* %local_n.11, align 4
# toR t107
# toR local_n.11
#   - ['movq -8(%rbp), %r9']
# >   %t108 = add i64 0, 10
# toR i64 0
# toR i64 10
# toR t108
#   - ['movq $0, %r8', 'addq $10, %r8']
# >   %t106 = sdiv i64 %t107, %t108
# toR t107
# toR t108
# toR t106
#   - ['pushq %rax', 'pushq %rdx', 'movq %r9, %rax', 'cqto', 'idivq %r8', 'movq %rax, %r8', 'popq %rdx', 'popq %rax']
# >   call void @main_putInt(i64 %t106)
# toR t106
#   - ['movq %r8, %rdi', 'call main_putInt@PLT']
# >   br label %if.end7.100
#   - []
# >   %t111 = load i64, i64* %local_n.11, align 4
# toR t111
# toR local_n.11
#   - ['movq -8(%rbp), %r8']
# >   %t112 = add i64 0, 10
# toR i64 0
# toR i64 10
# toR t112
#   - ['movq $0, %r9', 'addq $10, %r9']
# >   %t110 = srem i64 %t111, %t112
# toR t111
# toR t112
# toR t110
#   - ['pushq %rax', 'pushq %rdx', 'movq %r8, %rax', 'cqto', 'idivq %r9', 'movq %rdx, %r8', 'popq %rdx', 'popq %rax']
# >   %t113 = add i64 0, 48
# toR i64 0
# toR i64 48
# toR t113
#   - ['movq $0, %r9', 'addq $48, %r9']
# >   %t109 = add i64 %t110, %t113
# toR t110
# toR t113
# toR t109
#   - ['movq %r8, %r8', 'addq %r9, %r8']
# >   %t114 = call i64 @putchar(i64 %t109)
# toR t114
# toR t109
#   - ['movq %r8, %rdi', 'call putchar@PLT', 'movq %rax, %r8']
# >   ret void
#   - ['jmp main_putInt_end']
# -- ASM: --
# 	.globl main_putInt
# 	main_putInt:
# pushq %rbp
# movq %rsp, %rbp
# subq $8, %rsp
# pushq %r8
# pushq %r9
# pushq %r10
# pushq %r11
# pushq %r12
# pushq %r13
# pushq %r14
# pushq %r15
#   #  store i64 %local_n.11.arg0, i64* %local_n.11, align 4
# movq %rdi, -8(%rbp)
#   #  %t90 = load i64, i64* %local_n.11, align 4
# movq -8(%rbp), %r8
#   #  %t91 = add i64 0, 0
# movq $0, %r9
# addq $0, %r9
#   #  %t89 = icmp slt i64 %t90, %t91
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setl %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t89, label %if.body6.86, label %if.end6.88
# cmpq $0, %r8
# je if.end6.88
# 	if.body6.86:
#   #  %t92 = add i64 0, 45
# movq $0, %r8
# addq $45, %r8
#   #  %t93 = call i64 @putchar(i64 %t92)
# movq %r8, %rdi
# call putchar@PLT
# movq %rax, %r8
#   #  %t95 = load i64, i64* %local_n.11, align 4
# movq -8(%rbp), %r8
#   #  %t94 = sub i64 0, %t95
# pushq %rcx
# movq %r8, %rcx
# movq $0, %r8
# subq %rcx, %r8
# popq %rcx
#   #  store i64 %t94, i64* %local_n.11, align 4
# movq %r8, -8(%rbp)
#   #  br label %if.end6.88
# 	if.end6.88:
#   #  %t103 = load i64, i64* %local_n.11, align 4
# movq -8(%rbp), %r8
#   #  %t104 = add i64 0, 10
# movq $0, %r9
# addq $10, %r9
#   #  %t102 = sdiv i64 %t103, %t104
# pushq %rax
# pushq %rdx
# movq %r8, %rax
# cqto
# idivq %r9
# movq %rax, %r8
# popq %rdx
# popq %rax
#   #  %t105 = add i64 0, 0
# movq $0, %r9
# addq $0, %r9
#   #  %t101 = icmp ne i64 %t102, %t105
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setne %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t101, label %if.body7.98, label %if.end7.100
# cmpq $0, %r8
# je if.end7.100
# 	if.body7.98:
#   #  %t107 = load i64, i64* %local_n.11, align 4
# movq -8(%rbp), %r9
#   #  %t108 = add i64 0, 10
# movq $0, %r8
# addq $10, %r8
#   #  %t106 = sdiv i64 %t107, %t108
# pushq %rax
# pushq %rdx
# movq %r9, %rax
# cqto
# idivq %r8
# movq %rax, %r8
# popq %rdx
# popq %rax
#   #  call void @main_putInt(i64 %t106)
# movq %r8, %rdi
# call main_putInt@PLT
#   #  br label %if.end7.100
# 	if.end7.100:
#   #  %t111 = load i64, i64* %local_n.11, align 4
# movq -8(%rbp), %r8
#   #  %t112 = add i64 0, 10
# movq $0, %r9
# addq $10, %r9
#   #  %t110 = srem i64 %t111, %t112
# pushq %rax
# pushq %rdx
# movq %r8, %rax
# cqto
# idivq %r9
# movq %rdx, %r8
# popq %rdx
# popq %rax
#   #  %t113 = add i64 0, 48
# movq $0, %r9
# addq $48, %r9
#   #  %t109 = add i64 %t110, %t113
# movq %r8, %r8
# addq %r9, %r8
#   #  %t114 = call i64 @putchar(i64 %t109)
# movq %r8, %rdi
# call putchar@PLT
# movq %rax, %r8
#   #  ret void
# jmp main_putInt_end
# 	main_putInt_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
# codeGenForFunc main_putIntW
# {'for.4.cond': 9, 'for.4.body': 13, 'for.4.post': 25, 'for.4.end': 26, 'if.body9.134': 34, 'if.end9.136': 38, 'for.5.cond': 41, 'for.5.body': 45, 'for.5.post': 48, 'for.5.end': 52, 'if.body11.152': 56, 'if.end11.154': 62, 'for.6.cond': 71, 'for.6.body': 75, 'for.6.post': 90, 'for.6.end': 94}
#   br label %for.4.cond
#   br i1 %t118, label %for.4.body, label %for.4.end
#   br label %for.4.post
#   br label %for.4.cond
#   br i1 %t137, label %if.body9.134, label %if.end9.136
#   br label %if.end9.136
#   br label %for.5.cond
#   br i1 %t143, label %for.5.body, label %for.5.end
#   br label %for.5.post
#   br label %for.5.cond
#   br i1 %t155, label %if.body11.152, label %if.end11.154
#   br label %if.end11.154
#   br label %for.6.cond
#   br i1 %t168, label %for.6.body, label %for.6.end
#   br label %for.6.post
#   br label %for.6.cond
# 0 [[1], {'local_n.12.arg0'}, set()]
# 1 [[2], {'local_width.13.arg1'}, set()]
# 2 [[3], set(), {'t115'}]
# 3 [[4], {'t115'}, set()]
# 4 [[5], set(), {'t116'}]
# 5 [[6], {'t116'}, set()]
# 6 [[7], set(), {'t117'}]
# 7 [[8], {'t117'}, set()]
# 8 [[9], set(), set()]
# 9 [[10], set(), {'t119'}]
# 10 [[11], set(), {'t120'}]
# 11 [[12], {'t119', 't120'}, {'t118'}]
# 12 [[26, 13], {'t118'}, set()]
# 13 [[14], set(), {'t121'}]
# 14 [[15], {'t121'}, {'t122'}]
# 15 [[16], {'t122'}, set()]
# 16 [[17], set(), {'t124'}]
# 17 [[18], set(), {'t125'}]
# 18 [[19], {'t124', 't125'}, {'t123'}]
# 19 [[20], {'t123'}, set()]
# 20 [[21], set(), {'t127'}]
# 21 [[22], set(), {'t128'}]
# 22 [[23], {'t128', 't127'}, {'t126'}]
# 23 [[24], {'t126'}, set()]
# 24 [[25], set(), set()]
# 25 [[9], set(), set()]
# 26 [[27], set(), {'t130'}]
# 27 [[28], set(), {'t131'}]
# 28 [[29], {'t130', 't131'}, {'t129'}]
# 29 [[30], {'t129'}, set()]
# 30 [[31], set(), {'t138'}]
# 31 [[32], set(), {'t139'}]
# 32 [[33], {'t138', 't139'}, {'t137'}]
# 33 [[38, 34], {'t137'}, set()]
# 34 [[35], set(), {'t140'}]
# 35 [[36], {'t140'}, {'t141'}]
# 36 [[37], {'t141'}, set()]
# 37 [[38], set(), set()]
# 38 [[39], set(), {'t142'}]
# 39 [[40], {'t142'}, set()]
# 40 [[41], set(), set()]
# 41 [[42], set(), {'t144'}]
# 42 [[43], set(), {'t145'}]
# 43 [[44], {'t145', 't144'}, {'t143'}]
# 44 [[52, 45], {'t143'}, set()]
# 45 [[46], set(), {'t146'}]
# 46 [[47], {'t146'}, {'t147'}]
# 47 [[48], set(), set()]
# 48 [[49], set(), {'t148'}]
# 49 [[50], {'t148'}, {'t149'}]
# 50 [[51], {'t149'}, set()]
# 51 [[41], set(), set()]
# 52 [[53], set(), {'t156'}]
# 53 [[54], set(), {'t157'}]
# 54 [[55], {'t156', 't157'}, {'t155'}]
# 55 [[62, 56], {'t155'}, set()]
# 56 [[57], set(), {'t158'}]
# 57 [[58], {'t158'}, {'t159'}]
# 58 [[59], set(), {'t161'}]
# 59 [[60], {'t161'}, {'t160'}]
# 60 [[61], {'t160'}, set()]
# 61 [[62], set(), set()]
# 62 [[63], set(), {'t163'}]
# 63 [[64], set(), {'t164'}]
# 64 [[65], {'t163', 't164'}, {'t162'}]
# 65 [[66], {'t162'}, set()]
# 66 [[67], set(), {'t166'}]
# 67 [[68], set(), {'t167'}]
# 68 [[69], {'t166', 't167'}, {'t165'}]
# 69 [[70], {'t165'}, set()]
# 70 [[71], set(), set()]
# 71 [[72], set(), {'t169'}]
# 72 [[73], set(), {'t170'}]
# 73 [[74], {'t169', 't170'}, {'t168'}]
# 74 [[94, 75], {'t168'}, set()]
# 75 [[76], set(), {'t173'}]
# 76 [[77], set(), {'t174'}]
# 77 [[78], {'t173', 't174'}, {'t172'}]
# 78 [[79], set(), {'t175'}]
# 79 [[80], {'t175', 't172'}, {'t171'}]
# 80 [[81], {'t171'}, set()]
# 81 [[82], set(), {'t177'}]
# 82 [[83], set(), {'t178'}]
# 83 [[84], {'t178', 't177'}, {'t176'}]
# 84 [[85], {'t176'}, {'t179'}]
# 85 [[86], set(), {'t181'}]
# 86 [[87], set(), {'t182'}]
# 87 [[88], {'t182', 't181'}, {'t180'}]
# 88 [[89], {'t180'}, set()]
# 89 [[90], set(), set()]
# 90 [[91], set(), {'t183'}]
# 91 [[92], {'t183'}, {'t184'}]
# 92 [[93], {'t184'}, set()]
# 93 [[71], set(), set()]
# 94 [[], set(), set()]
# done
# count 3
# 0 {} {local_n.12.arg0} | {local_width.13.arg1, local_n.12.arg0} {local_width.13.arg1}
# 1 {} {local_width.13.arg1} | {local_width.13.arg1} {}
# 2 {t115} {} | {} {t115}
# 3 {} {t115} | {t115} {}
# 4 {t116} {} | {} {t116}
# 5 {} {t116} | {t116} {}
# 6 {t117} {} | {} {t117}
# 7 {} {t117} | {t117} {}
# 8 {} {} | {} {}
# 9 {t119} {} | {} {t119}
# 10 {t120} {} | {t119} {t119, t120}
# 11 {t118} {t119, t120} | {t119, t120} {t118}
# 12 {} {t118} | {t118} {}
# 13 {t121} {} | {} {t121}
# 14 {t122} {t121} | {t121} {t122}
# 15 {} {t122} | {t122} {}
# 16 {t124} {} | {} {t124}
# 17 {t125} {} | {t124} {t124, t125}
# 18 {t123} {t124, t125} | {t124, t125} {t123}
# 19 {} {t123} | {t123} {}
# 20 {t127} {} | {} {t127}
# 21 {t128} {} | {t127} {t128, t127}
# 22 {t126} {t128, t127} | {t128, t127} {t126}
# 23 {} {t126} | {t126} {}
# 24 {} {} | {} {}
# 25 {} {} | {} {}
# 26 {t130} {} | {} {t130}
# 27 {t131} {} | {t130} {t130, t131}
# 28 {t129} {t130, t131} | {t130, t131} {t129}
# 29 {} {t129} | {t129} {}
# 30 {t138} {} | {} {t138}
# 31 {t139} {} | {t138} {t138, t139}
# 32 {t137} {t138, t139} | {t138, t139} {t137}
# 33 {} {t137} | {t137} {}
# 34 {t140} {} | {} {t140}
# 35 {t141} {t140} | {t140} {t141}
# 36 {} {t141} | {t141} {}
# 37 {} {} | {} {}
# 38 {t142} {} | {} {t142}
# 39 {} {t142} | {t142} {}
# 40 {} {} | {} {}
# 41 {t144} {} | {} {t144}
# 42 {t145} {} | {t144} {t145, t144}
# 43 {t143} {t145, t144} | {t145, t144} {t143}
# 44 {} {t143} | {t143} {}
# 45 {t146} {} | {} {t146}
# 46 {t147} {t146} | {t146} {}
# 47 {} {} | {} {}
# 48 {t148} {} | {} {t148}
# 49 {t149} {t148} | {t148} {t149}
# 50 {} {t149} | {t149} {}
# 51 {} {} | {} {}
# 52 {t156} {} | {} {t156}
# 53 {t157} {} | {t156} {t156, t157}
# 54 {t155} {t156, t157} | {t156, t157} {t155}
# 55 {} {t155} | {t155} {}
# 56 {t158} {} | {} {t158}
# 57 {t159} {t158} | {t158} {}
# 58 {t161} {} | {} {t161}
# 59 {t160} {t161} | {t161} {t160}
# 60 {} {t160} | {t160} {}
# 61 {} {} | {} {}
# 62 {t163} {} | {} {t163}
# 63 {t164} {} | {t163} {t163, t164}
# 64 {t162} {t163, t164} | {t163, t164} {t162}
# 65 {} {t162} | {t162} {}
# 66 {t166} {} | {} {t166}
# 67 {t167} {} | {t166} {t166, t167}
# 68 {t165} {t166, t167} | {t166, t167} {t165}
# 69 {} {t165} | {t165} {}
# 70 {} {} | {} {}
# 71 {t169} {} | {} {t169}
# 72 {t170} {} | {t169} {t169, t170}
# 73 {t168} {t169, t170} | {t169, t170} {t168}
# 74 {} {t168} | {t168} {}
# 75 {t173} {} | {} {t173}
# 76 {t174} {} | {t173} {t173, t174}
# 77 {t172} {t173, t174} | {t173, t174} {t172}
# 78 {t175} {} | {t172} {t175, t172}
# 79 {t171} {t175, t172} | {t175, t172} {t171}
# 80 {} {t171} | {t171} {}
# 81 {t177} {} | {} {t177}
# 82 {t178} {} | {t177} {t178, t177}
# 83 {t176} {t178, t177} | {t178, t177} {t176}
# 84 {t179} {t176} | {t176} {}
# 85 {t181} {} | {} {t181}
# 86 {t182} {} | {t181} {t182, t181}
# 87 {t180} {t182, t181} | {t182, t181} {t180}
# 88 {} {t180} | {t180} {}
# 89 {} {} | {} {}
# 90 {t183} {} | {} {t183}
# 91 {t184} {t183} | {t183} {t184}
# 92 {} {t184} | {t184} {}
# 93 {} {} | {} {}
# 94 {} {} | {} {}
# {'local_n.12': 8, 'local_width.13': 8, 'local_digits.14': 8, 'local_goDown.15': 8, 'local_goUp.16': 8, 'local_spaces.17': 8, 'local_i.18': 8, 'local_i.19': 8, 'local_d.20': 8}
# 72
# {'t161', 't163', 't140', 't172', 't162', 't177', 't147', 't178', 't182', 't169', 't170', 't184', 't156', 't116', 'local_width.13.arg1', 't128', 't183', 't126', 't146', 't155', 't171', 't164', 't129', 't123', 't131', 't149', 't143', 't115', 't121', 'local_n.12.arg0', 't175', 't117', 't180', 't124', 't120', 't141', 't165', 't166', 't179', 't138', 't159', 't137', 't168', 't119', 't148', 't167', 't145', 't174', 't173', 't125', 't127', 't142', 't160', 't122', 't158', 't157', 't130', 't181', 't176', 't118', 't144', 't139'}
# add t120 t119
# add t125 t124
# add t128 t127
# add t131 t130
# add t139 t138
# add t145 t144
# add t157 t156
# add t164 t163
# add t167 t166
# add t170 t169
# add t174 t173
# add t175 t172
# add t178 t177
# add t182 t181
# coloring {'t139': 0, 't144': 0, 't118': 0, 't176': 0, 't181': 0, 't130': 0, 't157': 0, 't158': 0, 't122': 0, 't160': 0, 't142': 0, 't127': 0, 't125': 0, 't173': 0, 't174': 1, 't145': 1, 't167': 0, 't148': 0, 't119': 0, 't168': 0, 't137': 0, 't159': 0, 't138': 1, 't179': 0, 't166': 1, 't165': 0, 't141': 0, 't120': 1, 't124': 1, 't180': 0, 't117': 0, 't175': 0, 'local_n.12.arg0': 0, 't121': 0, 't115': 0, 't143': 0, 't149': 0, 't131': 1, 't123': 0, 't129': 0, 't164': 0, 't171': 0, 't155': 0, 't146': 0, 't126': 0, 't183': 0, 't128': 1, 'local_width.13.arg1': 0, 't116': 0, 't156': 1, 't184': 0, 't170': 0, 't169': 1, 't182': 1, 't178': 0, 't147': 0, 't177': 1, 't162': 0, 't172': 1, 't140': 0, 't163': 1, 't161': 0}
# single nodes: {'t161', 't140', 't147', 't162', 't184', 't116', 'local_width.13.arg1', 't183', 't171', 't146', 't126', 't155', 't129', 't123', 't149', 't143', 't115', 't121', 'local_n.12.arg0', 't117', 't180', 't141', 't165', 't179', 't159', 't137', 't168', 't148', 't160', 't142', 't122', 't158', 't176', 't118'}
# color needed: 2
# depth {'local_n.12': 8, 'local_width.13': 16, 'local_digits.14': 24, 'local_goDown.15': 32, 'local_goUp.16': 40, 'local_spaces.17': 48, 'local_i.18': 56, 'local_i.19': 64, 'local_d.20': 72}
# >   store i64 %local_n.12.arg0, i64* %local_n.12, align 4
# toR local_n.12.arg0
# toR local_n.12
#   - ['movq %rdi, -8(%rbp)']
# >   store i64 %local_width.13.arg1, i64* %local_width.13, align 4
# toR local_width.13.arg1
# toR local_width.13
#   - ['movq %rsi, -16(%rbp)']
# >   %t115 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t115
#   - ['movq $0, %r8', 'addq $0, %r8']
# >   store i64 %t115, i64* %local_digits.14, align 4
# toR t115
# toR local_digits.14
#   - ['movq %r8, -24(%rbp)']
# >   %t116 = load i64, i64* %local_n.12, align 4
# toR t116
# toR local_n.12
# ...
#   #  br i1 %t324, label %for.11.body, label %for.11.end
# cmpq $0, %r8
# je for.11.end
# 	for.11.body:
#   #  %t327 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  store i64 %t327, i64* %local_sum.46, align 4
# movq %r8, -88(%rbp)
#   #  %t328 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  store i64 %t328, i64* %local_k.47, align 4
# movq %r8, -96(%rbp)
#   #  br label %for.10.cond
# 	for.10.cond:
#   #  %t330 = load i64, i64* %local_k.47, align 4
# movq -96(%rbp), %r9
#   #  %t331 = load i64, i64* %local_ac.39, align 4
# movq -32(%rbp), %r8
#   #  %t329 = icmp slt i64 %t330, %t331
# pushq %rax
# movq $0, %rax
# cmpq %r8, %r9
# setl %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t329, label %for.10.body, label %for.10.end
# cmpq $0, %r8
# je for.10.end
# 	for.10.body:
#   #  %t333 = load i64, i64* %local_sum.46, align 4
# movq -88(%rbp), %r9
#   #  %t335 = load i64, i64* %local_i.43, align 4
# movq -64(%rbp), %r10
#   #  %t336 = load i64**, i64*** %local_matrixA.36, align 4
# movq -8(%rbp), %r8
#   #  %t337 = getelementptr inbounds i64*, i64** %t336, i64 %t335
# leaq (%r8,%r10,8), %r8
#   #  %t338 = load i64, i64* %local_k.47, align 4
# movq -96(%rbp), %r10
#   #  %t339 = load i64*, i64** %t337, align 4
# movq (%r8), %r8
#   #  %t340 = getelementptr inbounds i64, i64* %t339, i64 %t338
# leaq (%r8,%r10,8), %r8
#   #  %t341 = load i64, i64* %t340, align 4
# movq (%r8), %r11
#   #  %t342 = load i64, i64* %local_k.47, align 4
# movq -96(%rbp), %r10
#   #  %t343 = load i64**, i64*** %local_matrixB.37, align 4
# movq -16(%rbp), %r8
#   #  %t344 = getelementptr inbounds i64*, i64** %t343, i64 %t342
# leaq (%r8,%r10,8), %r8
#   #  %t345 = load i64, i64* %local_j.45, align 4
# movq -80(%rbp), %r10
#   #  %t346 = load i64*, i64** %t344, align 4
# movq (%r8), %r8
#   #  %t347 = getelementptr inbounds i64, i64* %t346, i64 %t345
# leaq (%r8,%r10,8), %r8
#   #  %t348 = load i64, i64* %t347, align 4
# movq (%r8), %r8
#   #  %t334 = mul i64 %t341, %t348
# pushq %rax
# pushq %rdx
# movq %r11, %rax
# imulq %r8
# movq %rax, %r8
# popq %rdx
# popq %rax
#   #  %t332 = add i64 %t333, %t334
# movq %r8, %r8
# addq %r9, %r8
#   #  store i64 %t332, i64* %local_sum.46, align 4
# movq %r8, -88(%rbp)
#   #  br label %for.10.post
# 	for.10.post:
#   #  %t349 = load i64, i64* %local_k.47, align 4
# movq -96(%rbp), %r8
#   #  %t350 = add i64 %t349, 1
# movq %r8, %r8
# addq $1, %r8
#   #  store i64 %t350, i64* %local_k.47, align 4
# movq %r8, -96(%rbp)
#   #  br label %for.10.cond
# jmp for.10.cond
# 	for.10.end:
#   #  %t351 = load i64, i64* %local_sum.46, align 4
# movq -88(%rbp), %r9
#   #  %t352 = load i64, i64* %local_j.45, align 4
# movq -80(%rbp), %r8
#   #  %t353 = load i64*, i64** %local_row.44, align 4
# movq -72(%rbp), %r10
#   #  %t354 = getelementptr inbounds i64, i64* %t353, i64 %t352
# leaq (%r10,%r8,8), %r8
#   #  store i64 %t351, i64* %t354, align 4
# movq %r9, (%r8)
#   #  br label %for.11.post
# 	for.11.post:
#   #  %t355 = load i64, i64* %local_j.45, align 4
# movq -80(%rbp), %r8
#   #  %t356 = add i64 %t355, 1
# movq %r8, %r8
# addq $1, %r8
#   #  store i64 %t356, i64* %local_j.45, align 4
# movq %r8, -80(%rbp)
#   #  br label %for.11.cond
# jmp for.11.cond
# 	for.11.end:
#   #  %t357 = load i64*, i64** %local_row.44, align 4
# movq -72(%rbp), %r10
#   #  %t358 = load i64, i64* %local_i.43, align 4
# movq -64(%rbp), %r8
#   #  %t359 = load i64**, i64*** %local_result.42, align 4
# movq -56(%rbp), %r9
#   #  %t360 = getelementptr inbounds i64*, i64** %t359, i64 %t358
# leaq (%r9,%r8,8), %r8
#   #  store i64* %t357, i64** %t360, align 8
# movq %r10, (%r8)
#   #  br label %for.12.post
# 	for.12.post:
#   #  %t361 = load i64, i64* %local_i.43, align 4
# movq -64(%rbp), %r8
#   #  %t362 = add i64 %t361, 1
# movq %r8, %r8
# addq $1, %r8
#   #  store i64 %t362, i64* %local_i.43, align 4
# movq %r8, -64(%rbp)
#   #  br label %for.12.cond
# jmp for.12.cond
# 	for.12.end:
#   #  %t363 = load i64**, i64*** %local_result.42, align 4
# movq -56(%rbp), %r8
#   #  ret i64** %t363
# movq %r8, %rax
# jmp main_calculateProduct_end
# 	main_calculateProduct_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
# codeGenForFunc main_outputMatrix
# {'for.14.cond': 6, 'for.14.body': 10, 'for.13.cond': 13, 'for.13.body': 17, 'for.13.post': 27, 'for.13.end': 31, 'for.14.post': 34, 'for.14.end': 38}
#   br label %for.14.cond
#   br i1 %t365, label %for.14.body, label %for.14.end
#   br label %for.13.cond
#   br i1 %t369, label %for.13.body, label %for.13.end
#   br label %for.13.post
#   br label %for.13.cond
#   br label %for.14.post
#   br label %for.14.cond
# 0 [[1], {'local_matrix.48.arg0'}, set()]
# 1 [[2], {'local_rows.49.arg1'}, set()]
# 2 [[3], {'local_cols.50.arg2'}, set()]
# 3 [[4], set(), {'t364'}]
# 4 [[5], {'t364'}, set()]
# 5 [[6], set(), set()]
# 6 [[7], set(), {'t366'}]
# 7 [[8], set(), {'t367'}]
# 8 [[9], {'t366', 't367'}, {'t365'}]
# 9 [[38, 10], {'t365'}, set()]
# 10 [[11], set(), {'t368'}]
# 11 [[12], {'t368'}, set()]
# 12 [[13], set(), set()]
# 13 [[14], set(), {'t370'}]
# 14 [[15], set(), {'t371'}]
# 15 [[16], {'t371', 't370'}, {'t369'}]
# 16 [[31, 17], {'t369'}, set()]
# 17 [[18], set(), {'t372'}]
# 18 [[19], set(), {'t373'}]
# 19 [[20], {'t373', 't372'}, {'t374'}]
# 20 [[21], set(), {'t375'}]
# 21 [[22], {'t374'}, {'t376'}]
# 22 [[23], {'t375', 't376'}, {'t377'}]
# 23 [[24], {'t377'}, {'t378'}]
# 24 [[25], set(), {'t379'}]
# 25 [[26], {'t379', 't378'}, set()]
# 26 [[27], set(), set()]
# 27 [[28], set(), {'t380'}]
# 28 [[29], {'t380'}, {'t381'}]
# 29 [[30], {'t381'}, set()]
# 30 [[13], set(), set()]
# 31 [[32], set(), {'t382'}]
# 32 [[33], {'t382'}, {'t383'}]
# 33 [[34], set(), set()]
# 34 [[35], set(), {'t384'}]
# 35 [[36], {'t384'}, {'t385'}]
# 36 [[37], {'t385'}, set()]
# 37 [[6], set(), set()]
# 38 [[], set(), set()]
# done
# count 4
# 0 {} {local_matrix.48.arg0} | {local_cols.50.arg2, local_rows.49.arg1, local_matrix.48.arg0} {local_cols.50.arg2, local_rows.49.arg1}
# 1 {} {local_rows.49.arg1} | {local_cols.50.arg2, local_rows.49.arg1} {local_cols.50.arg2}
# 2 {} {local_cols.50.arg2} | {local_cols.50.arg2} {}
# 3 {t364} {} | {} {t364}
# 4 {} {t364} | {t364} {}
# 5 {} {} | {} {}
# 6 {t366} {} | {} {t366}
# 7 {t367} {} | {t366} {t366, t367}
# 8 {t365} {t366, t367} | {t366, t367} {t365}
# 9 {} {t365} | {t365} {}
# 10 {t368} {} | {} {t368}
# 11 {} {t368} | {t368} {}
# 12 {} {} | {} {}
# 13 {t370} {} | {} {t370}
# 14 {t371} {} | {t370} {t371, t370}
# 15 {t369} {t371, t370} | {t371, t370} {t369}
# 16 {} {t369} | {t369} {}
# 17 {t372} {} | {} {t372}
# 18 {t373} {} | {t372} {t373, t372}
# 19 {t374} {t373, t372} | {t373, t372} {t374}
# 20 {t375} {} | {t374} {t374, t375}
# 21 {t376} {t374} | {t374, t375} {t375, t376}
# 22 {t377} {t375, t376} | {t375, t376} {t377}
# 23 {t378} {t377} | {t377} {t378}
# 24 {t379} {} | {t378} {t379, t378}
# 25 {} {t379, t378} | {t379, t378} {}
# 26 {} {} | {} {}
# 27 {t380} {} | {} {t380}
# 28 {t381} {t380} | {t380} {t381}
# 29 {} {t381} | {t381} {}
# 30 {} {} | {} {}
# 31 {t382} {} | {} {t382}
# 32 {t383} {t382} | {t382} {}
# 33 {} {} | {} {}
# 34 {t384} {} | {} {t384}
# 35 {t385} {t384} | {t384} {t385}
# 36 {} {t385} | {t385} {}
# 37 {} {} | {} {}
# 38 {} {} | {} {}
# {'local_matrix.48': 8, 'local_rows.49': 8, 'local_cols.50': 8, 'local_i.51': 8, 'local_j.52': 8}
# 40
# {'t379', 't365', 'local_rows.49.arg1', 't374', 't383', 't373', 'local_matrix.48.arg0', 't380', 't382', 't384', 't364', 't385', 't369', 't367', 't375', 't377', 't366', 't378', 't368', 'local_cols.50.arg2', 't372', 't381', 't371', 't370', 't376'}
# add t367 t366
# add t371 t370
# add t373 t372
# add t375 t374
# add t376 t375
# add t379 t378
# coloring {'t376': 0, 't370': 0, 't371': 1, 't381': 0, 't372': 0, 'local_cols.50.arg2': 0, 't368': 0, 't378': 0, 't366': 0, 't377': 0, 't375': 1, 't367': 1, 't369': 0, 't385': 0, 't364': 0, 't384': 0, 't382': 0, 't380': 0, 'local_matrix.48.arg0': 0, 't373': 1, 't383': 0, 't374': 0, 'local_rows.49.arg1': 0, 't365': 0, 't379': 1}
# single nodes: {'t365', 'local_rows.49.arg1', 't383', 't377', 'local_matrix.48.arg0', 't380', 't382', 't368', 't384', 'local_cols.50.arg2', 't381', 't364', 't385', 't369'}
# color needed: 2
# depth {'local_matrix.48': 8, 'local_rows.49': 16, 'local_cols.50': 24, 'local_i.51': 32, 'local_j.52': 40}
# >   store i64** %local_matrix.48.arg0, i64*** %local_matrix.48, align 8
# toR local_matrix.48.arg0
# toR local_matrix.48
#   - ['movq %rdi, -8(%rbp)']
# >   store i64 %local_rows.49.arg1, i64* %local_rows.49, align 4
# toR local_rows.49.arg1
# toR local_rows.49
#   - ['movq %rsi, -16(%rbp)']
# >   store i64 %local_cols.50.arg2, i64* %local_cols.50, align 4
# toR local_cols.50.arg2
# toR local_cols.50
#   - ['movq %rdx, -24(%rbp)']
# >   %t364 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t364
#   - ['movq $0, %r8', 'addq $0, %r8']
# >   store i64 %t364, i64* %local_i.51, align 4
# toR t364
# toR local_i.51
#   - ['movq %r8, -32(%rbp)']
# >   br label %for.14.cond
#   - []
# >   %t366 = load i64, i64* %local_i.51, align 4
# toR t366
# toR local_i.51
#   - ['movq -32(%rbp), %r8']
# >   %t367 = load i64, i64* %local_rows.49, align 4
# toR t367
# toR local_rows.49
#   - ['movq -16(%rbp), %r9']
# >   %t365 = icmp slt i64 %t366, %t367
# toR t366
# toR t367
# toR t365
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setl %al', 'movq %rax, %r8', 'popq %rax']
# >   br i1 %t365, label %for.14.body, label %for.14.end
# toR t365
#   - ['cmpq $0, %r8', 'je for.14.end']
# >   %t368 = add i64 0, 0
# toR i64 0
# toR i64 0
# toR t368
#   - ['movq $0, %r8', 'addq $0, %r8']
# >   store i64 %t368, i64* %local_j.52, align 4
# toR t368
# toR local_j.52
#   - ['movq %r8, -40(%rbp)']
# >   br label %for.13.cond
#   - []
# >   %t370 = load i64, i64* %local_j.52, align 4
# toR t370
# toR local_j.52
#   - ['movq -40(%rbp), %r8']
# >   %t371 = load i64, i64* %local_cols.50, align 4
# toR t371
# toR local_cols.50
#   - ['movq -24(%rbp), %r9']
# >   %t369 = icmp slt i64 %t370, %t371
# toR t370
# toR t371
# toR t369
#   - ['pushq %rax', 'movq $0, %rax', 'cmpq %r9, %r8', 'setl %al', 'movq %rax, %r8', 'popq %rax']
# >   br i1 %t369, label %for.13.body, label %for.13.end
# toR t369
#   - ['cmpq $0, %r8', 'je for.13.end']
# >   %t372 = load i64, i64* %local_i.51, align 4
# toR t372
# toR local_i.51
#   - ['movq -32(%rbp), %r8']
# >   %t373 = load i64**, i64*** %local_matrix.48, align 4
# toR t373
# toR local_matrix.48
#   - ['movq -8(%rbp), %r9']
# >   %t374 = getelementptr inbounds i64*, i64** %t373, i64 %t372
# toR t373
# toR t372
# toR t374
#   - ['leaq (%r9,%r8,8), %r8']
# >   %t375 = load i64, i64* %local_j.52, align 4
# toR t375
# toR local_j.52
#   - ['movq -40(%rbp), %r9']
# >   %t376 = load i64*, i64** %t374, align 4
# toR t376
# toR t374
#   - ['movq (%r8), %r8']
# >   %t377 = getelementptr inbounds i64, i64* %t376, i64 %t375
# toR t376
# toR t375
# toR t377
#   - ['leaq (%r8,%r9,8), %r8']
# >   %t378 = load i64, i64* %t377, align 4
# toR t378
# toR t377
#   - ['movq (%r8), %r8']
# >   %t379 = add i64 0, 10
# toR i64 0
# toR i64 10
# toR t379
#   - ['movq $0, %r9', 'addq $10, %r9']
# >   call void @main_putIntW(i64 %t378, i64 %t379)
# toR t378
# toR t379
#   - ['movq %r8, %rdi', 'movq %r9, %rsi', 'call main_putIntW@PLT']
# >   br label %for.13.post
#   - []
# >   %t380 = load i64, i64* %local_j.52, align 4
# toR t380
# toR local_j.52
#   - ['movq -40(%rbp), %r8']
# >   %t381 = add i64 %t380, 1
# toR t380
# toR i64 1
# toR t381
#   - ['movq %r8, %r8', 'addq $1, %r8']
# >   store i64 %t381, i64* %local_j.52, align 4
# toR t381
# toR local_j.52
#   - ['movq %r8, -40(%rbp)']
# >   br label %for.13.cond
#   - ['jmp for.13.cond']
# >   %t382 = add i64 0, 10
# toR i64 0
# toR i64 10
# toR t382
#   - ['movq $0, %r8', 'addq $10, %r8']
# >   %t383 = call i64 @putchar(i64 %t382)
# toR t383
# toR t382
#   - ['movq %r8, %rdi', 'call putchar@PLT', 'movq %rax, %r8']
# >   br label %for.14.post
#   - []
# >   %t384 = load i64, i64* %local_i.51, align 4
# toR t384
# toR local_i.51
#   - ['movq -32(%rbp), %r8']
# >   %t385 = add i64 %t384, 1
# toR t384
# toR i64 1
# toR t385
#   - ['movq %r8, %r8', 'addq $1, %r8']
# >   store i64 %t385, i64* %local_i.51, align 4
# toR t385
# toR local_i.51
#   - ['movq %r8, -32(%rbp)']
# >   br label %for.14.cond
#   - ['jmp for.14.cond']
# >   ret void
#   - ['jmp main_outputMatrix_end']
# -- ASM: --
# 	.globl main_outputMatrix
# 	main_outputMatrix:
# pushq %rbp
# movq %rsp, %rbp
# subq $40, %rsp
# pushq %r8
# pushq %r9
# pushq %r10
# pushq %r11
# pushq %r12
# pushq %r13
# pushq %r14
# pushq %r15
#   #  store i64** %local_matrix.48.arg0, i64*** %local_matrix.48, align 8
# movq %rdi, -8(%rbp)
#   #  store i64 %local_rows.49.arg1, i64* %local_rows.49, align 4
# movq %rsi, -16(%rbp)
#   #  store i64 %local_cols.50.arg2, i64* %local_cols.50, align 4
# movq %rdx, -24(%rbp)
#   #  %t364 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  store i64 %t364, i64* %local_i.51, align 4
# movq %r8, -32(%rbp)
#   #  br label %for.14.cond
# 	for.14.cond:
#   #  %t366 = load i64, i64* %local_i.51, align 4
# movq -32(%rbp), %r8
#   #  %t367 = load i64, i64* %local_rows.49, align 4
# movq -16(%rbp), %r9
#   #  %t365 = icmp slt i64 %t366, %t367
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setl %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t365, label %for.14.body, label %for.14.end
# cmpq $0, %r8
# je for.14.end
# 	for.14.body:
#   #  %t368 = add i64 0, 0
# movq $0, %r8
# addq $0, %r8
#   #  store i64 %t368, i64* %local_j.52, align 4
# movq %r8, -40(%rbp)
#   #  br label %for.13.cond
# 	for.13.cond:
#   #  %t370 = load i64, i64* %local_j.52, align 4
# movq -40(%rbp), %r8
#   #  %t371 = load i64, i64* %local_cols.50, align 4
# movq -24(%rbp), %r9
#   #  %t369 = icmp slt i64 %t370, %t371
# pushq %rax
# movq $0, %rax
# cmpq %r9, %r8
# setl %al
# movq %rax, %r8
# popq %rax
#   #  br i1 %t369, label %for.13.body, label %for.13.end
# cmpq $0, %r8
# je for.13.end
# 	for.13.body:
#   #  %t372 = load i64, i64* %local_i.51, align 4
# movq -32(%rbp), %r8
#   #  %t373 = load i64**, i64*** %local_matrix.48, align 4
# movq -8(%rbp), %r9
#   #  %t374 = getelementptr inbounds i64*, i64** %t373, i64 %t372
# leaq (%r9,%r8,8), %r8
#   #  %t375 = load i64, i64* %local_j.52, align 4
# movq -40(%rbp), %r9
#   #  %t376 = load i64*, i64** %t374, align 4
# movq (%r8), %r8
#   #  %t377 = getelementptr inbounds i64, i64* %t376, i64 %t375
# leaq (%r8,%r9,8), %r8
#   #  %t378 = load i64, i64* %t377, align 4
# movq (%r8), %r8
#   #  %t379 = add i64 0, 10
# movq $0, %r9
# addq $10, %r9
#   #  call void @main_putIntW(i64 %t378, i64 %t379)
# movq %r8, %rdi
# movq %r9, %rsi
# call main_putIntW@PLT
#   #  br label %for.13.post
# 	for.13.post:
#   #  %t380 = load i64, i64* %local_j.52, align 4
# movq -40(%rbp), %r8
#   #  %t381 = add i64 %t380, 1
# movq %r8, %r8
# addq $1, %r8
#   #  store i64 %t381, i64* %local_j.52, align 4
# movq %r8, -40(%rbp)
#   #  br label %for.13.cond
# jmp for.13.cond
# 	for.13.end:
#   #  %t382 = add i64 0, 10
# movq $0, %r8
# addq $10, %r8
#   #  %t383 = call i64 @putchar(i64 %t382)
# movq %r8, %rdi
# call putchar@PLT
# movq %rax, %r8
#   #  br label %for.14.post
# 	for.14.post:
#   #  %t384 = load i64, i64* %local_i.51, align 4
# movq -32(%rbp), %r8
#   #  %t385 = add i64 %t384, 1
# movq %r8, %r8
# addq $1, %r8
#   #  store i64 %t385, i64* %local_i.51, align 4
# movq %r8, -32(%rbp)
#   #  br label %for.14.cond
# jmp for.14.cond
# 	for.14.end:
#   #  ret void
# jmp main_outputMatrix_end
# 	main_outputMatrix_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
# codeGenForFunc main_init
# {}
# 0 [[], set(), set()]
# done
# count 1
# 0 {} {} | {} {}
# {}
# 0
# set()
# coloring {}
# single nodes: set()
# color needed: 0
# depth {}
# >   ret void
#   - ['jmp main_init_end']
# -- ASM: --
# 	.globl main_init
# 	main_init:
# pushq %rbp
# movq %rsp, %rbp
# subq $0, %rsp
# pushq %r8
# pushq %r9
# pushq %r10
# pushq %r11
# pushq %r12
# pushq %r13
# pushq %r14
# pushq %r15
#   #  ret void
# jmp main_init_end
# 	main_init_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
# codeGenForFunc main
# {}
# 0 [[1], set(), set()]
# 1 [[2], set(), set()]
# 2 [[], set(), set()]
# done
# count 1
# 0 {} {} | {} {}
# 1 {} {} | {} {}
# 2 {} {} | {} {}
# {}
# 0
# set()
# coloring {}
# single nodes: set()
# color needed: 0
# depth {}
# >   call void @main_init()
#   - ['call main_init@PLT']
# >   call void @main_main()
#   - ['call main_main@PLT']
# >   ret i64 0
# toR i64 0
#   - ['movq $0, %rax', 'jmp main_end']
# -- ASM: --
# 	.globl main
# 	main:
# pushq %rbp
# movq %rsp, %rbp
# subq $0, %rsp
# pushq %r8
# pushq %r9
# pushq %r10
# pushq %r11
# pushq %r12
# pushq %r13
# pushq %r14
# pushq %r15
#   #  call void @main_init()
# call main_init@PLT
#   #  call void @main_main()
# call main_main@PLT
#   #  ret i64 0
# movq $0, %rax
# jmp main_end
# 	main_end:
# popq %r15
# popq %r14
# popq %r13
# popq %r12
# popq %r11
# popq %r10
# popq %r9
# popq %r8
# movq %rbp, %rsp
# popq %rbp
# retq
